# %%
from shutil import copyfile
copyfile(src = "../usr/lib/modellib/modellib.py", dst = "../working/ModelLib.py")
# Out:
# '../working/ModelLib.py'

# %%
import numpy as np
import pandas as pd
import torch
from torch.utils.data import TensorDataset, Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from sklearn.model_selection import KFold,StratifiedKFold
from tqdm.auto import tqdm
from ModelLib import Create_model,stratified_group_k_fold
import random
import os
from copy import deepcopy
import math
from glob import glob

# %%
random.seed(831)
os.environ['PYTHONHASHSEED'] = str(721)
np.random.seed(1111)
torch.manual_seed(1117)
torch.cuda.manual_seed(1001)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# device = 'cpu'
device = 'cuda'

# %%
# train_x = np.load('../input/covid19fe/train_x.npy')
# test_x = np.load('../input/covid19fe/test_x.npy')
train_x = np.load('../input/covid19fe/train_aug_x.npy')
test_x = np.load('../input/covid19fe/test_aug_x.npy')
train_bpps = np.load('../input/covid19fe/train_bpps.npy')
test_bpps = np.load('../input/covid19fe/test_bpps.npy')
train_viennarna_bpps = np.load('../input/covid19extrafeatures/train_viennarna_bpps.npy')
test_viennarna_bpps = np.load('../input/covid19extrafeatures/test_viennarna_bpps.npy')
train_mat = np.load('../input/covid19extrafeatures/train_mat.npy')
test_mat = np.load('../input/covid19extrafeatures/test_mat.npy')
train_aug_mat = np.load('../input/covid19fe/train_aug_mat.npy')
test_aug_mat = np.load('../input/covid19fe/test_aug_mat.npy')
label = np.load('../input/covid19fe/label.npy')
label_error = np.load('../input/covid19fe/label_error.npy')
signal_to_noise = np.load('../input/covid19fe/signal_to_noise.npy')

# %%
train_bpps = np.concatenate([np.expand_dims(train_bpps,axis=1),np.expand_dims(train_viennarna_bpps,axis=1),np.expand_dims(train_mat,axis=1),np.expand_dims(train_aug_mat,axis=1)],axis=1)
test_bpps = np.concatenate([np.expand_dims(test_bpps,axis=1),np.expand_dims(test_viennarna_bpps,axis=1),np.expand_dims(test_mat,axis=1),np.expand_dims(test_aug_mat,axis=1)],axis=1)

# %%
train = pd.read_json('../input/stanford-covid-vaccine/train.json',lines=True).drop('index',axis=1)
test = pd.read_json('../input/stanford-covid-vaccine/test.json',lines=True).drop('index',axis=1)

train_length = train.seq_length.values
test_length = test.seq_length.values

train_scored = train.seq_scored.values
test_scored = test.seq_scored.values

SN_filter_mask = (train.SN_filter==1).values
SN_filter = np.where(SN_filter_mask)[0]
signal_filter = np.where(signal_to_noise > 1)[0]

# %%
# from sklearn.preprocessing import OneHotEncoder,scale
# from sklearn.cluster import KMeans
# cluster_features = OneHotEncoder().fit_transform(train_x[:,:107,0].reshape(-1,1)).toarray().reshape([len(train),-1])
# cluster_features = scale(cluster_features,axis=0)
# kmeans_model = KMeans(n_clusters=200, random_state=721).fit(cluster_features)
# cluster = kmeans_model.labels_

# %%
class Covid19Dataset(Dataset):
    def __init__(self,X,bpps,mat,seq_length,scored_length,label=None,label_error=None,signal_to_noise=None,SN_filter_mask=None):
        self.X = X.astype(np.int)
#         self.bpps = np.log(bpps + 1e-8).astype(np.float32)
        self.bpps = bpps.astype(np.float32)
        
#         self.bpps = np.log(bpps + 1e-8)
#         self.bpps = np.concatenate([bpps.reshape([-1,130,130,1]),mat.reshape([-1,130,130,1])],axis=-1).astype(np.float32)
        if label is not None:
            self.label = label.astype(np.float32)
            self.signal_to_noise = signal_to_noise.astype(np.float32)
            self.label_error=label_error.astype(np.float32)
            self.SN_filter_mask = SN_filter_mask
        else:
            self.label = None
        self.mask = np.zeros([len(X),130],dtype=bool)
        for i in range(len(seq_length)):
            if seq_length[i] < 130:
                self.mask[i,seq_length[i]:] = True
        self.scored_mask = np.ones([len(X),130],dtype=bool)
        for i in range(len(scored_length)):
            if scored_length[i] < 130:
                self.scored_mask[i,scored_length[i]:] = False
        self.seq_length = seq_length


    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        N = self.seq_length[idx]
        X = self.X[idx,:N]
        bpps = self.bpps[idx,:,:N,:N]
        mask = self.mask[idx,:N]
        scored_mask = self.scored_mask[idx,:N]
        if self.label is not None:
            label = self.label[idx,:N]
            label_error= self.label_error[idx,:N]
            signal_to_noise = self.signal_to_noise[idx]
            SN_filter_mask = self.SN_filter_mask[idx]
            return X,bpps,mask,scored_mask,label,label_error,signal_to_noise,SN_filter_mask
        else:
            return X,bpps,mask,scored_mask

# %%
nepochs = 300
n_fold = 5
kf = StratifiedKFold(n_fold,shuffle=True,random_state=831)

dataset = Covid19Dataset(train_x,train_bpps,train_mat,train_length,train_scored,label,label_error,signal_to_noise,SN_filter_mask)
cv_score = []
# cv_score = [0.20199335118134817, 0.19580934941768646, 0.19966551661491394]
loss_weights = torch.Tensor([1.2,1.2,1.2,0.7,0.7]).reshape(1,5).to(device)
oof = np.zeros([len(train_x),68,3])
# oof = np.load('temp_oof.npy')
for fold,(trn_group, test_group) in tqdm(enumerate(kf.split(train_x,SN_filter_mask)),total=n_fold):
#     trn_group = np.intersect1d(trn_group,signal_filter)
    test_group = np.intersect1d(test_group,SN_filter)
    traindataset = Covid19Dataset(train_x[trn_group],
                             train_bpps[trn_group],
                             train_mat[trn_group],
                             train_length[trn_group],
                             train_scored[trn_group],
                             label[trn_group],
                             label_error[trn_group],
                             signal_to_noise[trn_group],
                             SN_filter_mask[trn_group])
    valdataset = Covid19Dataset(train_x[test_group],
                             train_bpps[test_group],
                             train_mat[test_group],
                             train_length[test_group],
                             train_scored[test_group],
                             label[test_group],
                             label_error[test_group],
                             signal_to_noise[test_group],
                             SN_filter_mask[test_group])
    
    args_loader = {'batch_size': 128, 'shuffle': True, 'num_workers': 0, 'pin_memory': True, 'drop_last': True}
    train_loader = DataLoader(traindataset, **args_loader)
    args_loader = {'batch_size': 128, 'shuffle': False, 'num_workers': 0, 'pin_memory': True, 'drop_last': False}
    val_loader = DataLoader(valdataset, **args_loader)
    
    dataloaders = {'train' : train_loader, 'val' : val_loader}
    
    model,optimizer,scheduler = Create_model(device)
    best_model = {'reactivity':None,'deg_Mg_pH10':None,"deg_Mg_50C":None}
    best_loss = {'reactivity': np.inf,'deg_Mg_pH10': np.inf,'deg_Mg_50C': np.inf}
    for epoch in tqdm(range(nepochs)):
        epoch_loss = {'train': 0.0, 'val': 0.0, 'val_clean': 0.0, 'val_aug': 0.0,
                      'reactivity': 0.0,'deg_Mg_pH10': 0.0,'deg_Mg_50C': 0.0
                     }
        MA_loss = []
        test_pred = []
        test_pred_aug = []
        test_y = []
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
            else:
                model.eval()
            running_loss = 0.0
            for x_b,bpps_b,mask_b,scored_mask_b,label_b,label_error_b,signal_to_noise_b,SN_filter_mask_b in dataloaders[phase]:
                x_b = x_b.long().to(device)
                bpps_b = bpps_b.to(device)
                mask_b = mask_b.to(device)
                label_b = label_b.to(device)
                label_error_b = label_error_b.to(device)
                signal_to_noise_b = signal_to_noise_b.to(device).unsqueeze(1).unsqueeze(1)
                signal_to_noise_b = torch.clamp(signal_to_noise_b/4.5,0,10)
#                 signal_to_noise_b = torch.clamp(signal_to_noise_b/5,0,10)
#                 signal_to_noise_b = torch.clamp(torch.log(1 + signal_to_noise_b)/1.5,0,10)
#                 signal_to_noise_b = torch.sqrt(torch.clamp(signal_to_noise_b,0,999))/2

                label_error_b = torch.log(1+1.0/label_error_b[:,:68]) / 2.2496114573105803
    
                SN_filter_mask_b = SN_filter_mask_b.to(device)
                if phase=='train':
                    aug_mask = torch.randint(low=0,high=2,size=[len(bpps_b)],dtype=bool).to(device)
                    x_b[aug_mask,:,-4] = x_b[aug_mask,:,-2]
                    x_b[aug_mask,:,-3] = x_b[aug_mask,:,-1]
                    x_b = x_b[:,:,:-2]
                    bpps_b[aug_mask,-2] = bpps_b[aug_mask,-1]
                    bpps_b = bpps_b[:,:-1]
                else:
                    x_b_aug = x_b.clone()
                    x_b_aug[:,:,-4] = x_b_aug[:,:,-2]
                    x_b_aug[:,:,-3] = x_b_aug[:,:,-1]
                    x_b_aug  = x_b_aug[:,:,:-2]
                    bpps_b_aug = bpps_b.clone()
                    bpps_b_aug[:,-2] = bpps_b_aug[:,-1]
                    bpps_b_aug = bpps_b_aug[:,:-1]
                    
                    x_b = x_b[:,:,:-2]
                    bpps_b = bpps_b[:,:-1]
                
#                 if phase=='train':
#                     label_b += torch.normal(torch.zeros_like(label_b),1) * 0.001*label_error_b
                
                optimizer.zero_grad()
                with torch.set_grad_enabled(phase=='train'):
                    preds = model(x_b,bpps_b)
                    if phase=='val':
                        preds_aug = model(x_b_aug,bpps_b_aug)
                        preds2 = 0.5*(preds + preds_aug)
                        test_pred.append(preds[:,:68,:3].detach().cpu().numpy())
                        test_pred_aug.append(preds2[:,:68,:3].detach().cpu().numpy())
                        test_y.append(label_b[:,:68,:3].detach().cpu().numpy())

        
                    loss = (preds[:,:68] - label_b[:,:68])**2
                    loss = torch.sqrt((loss * signal_to_noise_b).reshape(-1,5).mean(0)).mean()
#                     loss = torch.sqrt((loss * signal_to_noise_b).reshape(-1,5)[:,:3].mean(0)).mean()
                
#                     loss = (preds[:,:68] - label_b[:,:68])**2
#                     loss = (label_error_b * loss).mean()

                    if phase=='train':
                        loss.backward()
                        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
                        optimizer.step()
#                         scheduler.step()
                if phase == 'train':
                    running_loss += loss.item() / len(dataloaders[phase])
                else:
                    running_loss += loss.item() / len(dataloaders[phase])
            if phase == 'train':
                epoch_loss['train'] = running_loss
            else:
                epoch_loss['val'] = running_loss
                test_pred = np.concatenate(test_pred,axis=0)
                test_pred_aug = np.concatenate(test_pred_aug,axis=0)
                test_y = np.concatenate(test_y,axis=0)
                epoch_loss['val_clean'] = np.sqrt(((test_pred-test_y)**2).reshape(-1,3).mean(0)).mean()
                res = ((test_pred_aug-test_y)**2).reshape(-1,3)
                epoch_loss['val_aug'] = np.sqrt(res.mean(0)).mean()
                epoch_loss['reactivity'] = np.sqrt(res[:,0].mean())
                epoch_loss['deg_Mg_pH10'] = np.sqrt(res[:,1].mean())
                epoch_loss['deg_Mg_50C'] = np.sqrt(res[:,2].mean())
        scheduler.step()
        print("Epoch {}/{}   -   loss: {:5.5f} - val_loss: {:5.5f} - val_clean_loss: {:5.5f} - val_aug_loss: {:5.5f} - reactivity: {:5.5f} - deg_Mg_pH10: {:5.5f} - deg_Mg_50C: {:5.5f}".format(epoch+1, nepochs, epoch_loss['train'], epoch_loss['val'], epoch_loss['val_clean'], epoch_loss['val_aug'], epoch_loss['reactivity'], epoch_loss['deg_Mg_pH10'], epoch_loss['deg_Mg_50C']))
        for i,cat in enumerate(['reactivity','deg_Mg_pH10','deg_Mg_50C']):
            if epoch_loss[cat] < best_loss[cat]:
                best_loss[cat] = epoch_loss[cat]
                torch.save(model.state_dict(), f'fold{fold+1}_{cat}_model.pt')
                oof[test_group,:,i] = test_pred_aug[:,:,i]
#     cv_score += best_score / 5
    cv_score.append(sum(best_loss.values())/3)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Ranger optimizer loaded.
# Gradient Centralization usage = False
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# /opt/conda/conda-bld/pytorch_1591914880026/work/torch/csrc/utils/python_arg_parser.cpp:756: UserWarning: This overload of addcmul_ is deprecated:
# 	addcmul_(Number value, Tensor tensor1, Tensor tensor2)
# Consider using one of the following signatures instead:
# 	addcmul_(Tensor tensor1, Tensor tensor2, *, Number value)
# Epoch 1/300   -   loss: 0.53991 - val_loss: 0.52912 - val_clean_loss: 0.47813 - val_aug_loss: 0.47828 - reactivity: 0.44463 - deg_Mg_pH10: 0.51555 - deg_Mg_50C: 0.47466
# Epoch 2/300   -   loss: 0.46525 - val_loss: 0.45463 - val_clean_loss: 0.41650 - val_aug_loss: 0.41722 - reactivity: 0.37165 - deg_Mg_pH10: 0.47330 - deg_Mg_50C: 0.40669
# Epoch 3/300   -   loss: 0.41719 - val_loss: 0.38921 - val_clean_loss: 0.36791 - val_aug_loss: 0.36854 - reactivity: 0.31898 - deg_Mg_pH10: 0.42639 - deg_Mg_50C: 0.36025
# Epoch 4/300   -   loss: 0.38816 - val_loss: 0.37502 - val_clean_loss: 0.35627 - val_aug_loss: 0.35653 - reactivity: 0.31227 - deg_Mg_pH10: 0.41051 - deg_Mg_50C: 0.34683
# Epoch 5/300   -   loss: 0.37246 - val_loss: 0.35624 - val_clean_loss: 0.34113 - val_aug_loss: 0.34045 - reactivity: 0.30241 - deg_Mg_pH10: 0.38812 - deg_Mg_50C: 0.33081
# Epoch 6/300   -   loss: 0.35808 - val_loss: 0.34260 - val_clean_loss: 0.32762 - val_aug_loss: 0.32726 - reactivity: 0.29097 - deg_Mg_pH10: 0.37377 - deg_Mg_50C: 0.31702
# Epoch 7/300   -   loss: 0.34780 - val_loss: 0.33405 - val_clean_loss: 0.31829 - val_aug_loss: 0.31795 - reactivity: 0.28880 - deg_Mg_pH10: 0.35758 - deg_Mg_50C: 0.30747
# Epoch 8/300   -   loss: 0.33799 - val_loss: 0.31813 - val_clean_loss: 0.30464 - val_aug_loss: 0.30457 - reactivity: 0.27724 - deg_Mg_pH10: 0.34379 - deg_Mg_50C: 0.29267
# Epoch 9/300   -   loss: 0.33099 - val_loss: 0.32254 - val_clean_loss: 0.30890 - val_aug_loss: 0.30856 - reactivity: 0.27936 - deg_Mg_pH10: 0.34645 - deg_Mg_50C: 0.29988
# Epoch 10/300   -   loss: 0.32324 - val_loss: 0.30518 - val_clean_loss: 0.29344 - val_aug_loss: 0.29351 - reactivity: 0.26690 - deg_Mg_pH10: 0.33003 - deg_Mg_50C: 0.28360
# Epoch 11/300   -   loss: 0.31704 - val_loss: 0.29964 - val_clean_loss: 0.28649 - val_aug_loss: 0.28643 - reactivity: 0.25990 - deg_Mg_pH10: 0.32278 - deg_Mg_50C: 0.27661
# Epoch 12/300   -   loss: 0.31164 - val_loss: 0.29392 - val_clean_loss: 0.28215 - val_aug_loss: 0.28250 - reactivity: 0.25948 - deg_Mg_pH10: 0.31747 - deg_Mg_50C: 0.27055
# Epoch 13/300   -   loss: 0.30515 - val_loss: 0.28465 - val_clean_loss: 0.27275 - val_aug_loss: 0.27288 - reactivity: 0.25304 - deg_Mg_pH10: 0.30731 - deg_Mg_50C: 0.25829
# Epoch 14/300   -   loss: 0.29822 - val_loss: 0.27985 - val_clean_loss: 0.26860 - val_aug_loss: 0.26850 - reactivity: 0.24992 - deg_Mg_pH10: 0.30152 - deg_Mg_50C: 0.25406
# Epoch 15/300   -   loss: 0.29313 - val_loss: 0.29253 - val_clean_loss: 0.28024 - val_aug_loss: 0.28035 - reactivity: 0.25963 - deg_Mg_pH10: 0.31167 - deg_Mg_50C: 0.26974
# Epoch 16/300   -   loss: 0.28947 - val_loss: 0.27275 - val_clean_loss: 0.26235 - val_aug_loss: 0.26237 - reactivity: 0.24488 - deg_Mg_pH10: 0.29524 - deg_Mg_50C: 0.24700
# Epoch 17/300   -   loss: 0.28480 - val_loss: 0.27341 - val_clean_loss: 0.26430 - val_aug_loss: 0.26465 - reactivity: 0.24487 - deg_Mg_pH10: 0.29835 - deg_Mg_50C: 0.25074
# Epoch 18/300   -   loss: 0.28111 - val_loss: 0.27428 - val_clean_loss: 0.26372 - val_aug_loss: 0.26381 - reactivity: 0.24407 - deg_Mg_pH10: 0.29687 - deg_Mg_50C: 0.25050
# Epoch 19/300   -   loss: 0.27784 - val_loss: 0.26457 - val_clean_loss: 0.25475 - val_aug_loss: 0.25473 - reactivity: 0.23650 - deg_Mg_pH10: 0.28841 - deg_Mg_50C: 0.23929
# Epoch 20/300   -   loss: 0.27589 - val_loss: 0.26089 - val_clean_loss: 0.25176 - val_aug_loss: 0.25180 - reactivity: 0.23338 - deg_Mg_pH10: 0.28530 - deg_Mg_50C: 0.23674
# Epoch 21/300   -   loss: 0.27150 - val_loss: 0.28233 - val_clean_loss: 0.27439 - val_aug_loss: 0.27417 - reactivity: 0.25676 - deg_Mg_pH10: 0.31016 - deg_Mg_50C: 0.25558
# Epoch 22/300   -   loss: 0.26882 - val_loss: 0.25881 - val_clean_loss: 0.25101 - val_aug_loss: 0.25079 - reactivity: 0.23390 - deg_Mg_pH10: 0.28336 - deg_Mg_50C: 0.23510
# Epoch 23/300   -   loss: 0.26566 - val_loss: 0.25977 - val_clean_loss: 0.25186 - val_aug_loss: 0.25145 - reactivity: 0.23199 - deg_Mg_pH10: 0.28417 - deg_Mg_50C: 0.23820
# Epoch 24/300   -   loss: 0.26418 - val_loss: 0.25211 - val_clean_loss: 0.24385 - val_aug_loss: 0.24366 - reactivity: 0.22565 - deg_Mg_pH10: 0.27653 - deg_Mg_50C: 0.22880
# Epoch 25/300   -   loss: 0.26112 - val_loss: 0.25666 - val_clean_loss: 0.24642 - val_aug_loss: 0.24622 - reactivity: 0.22836 - deg_Mg_pH10: 0.27808 - deg_Mg_50C: 0.23224
# Epoch 26/300   -   loss: 0.25873 - val_loss: 0.24762 - val_clean_loss: 0.23959 - val_aug_loss: 0.23931 - reactivity: 0.22215 - deg_Mg_pH10: 0.27242 - deg_Mg_50C: 0.22337
# Epoch 27/300   -   loss: 0.25848 - val_loss: 0.25576 - val_clean_loss: 0.24667 - val_aug_loss: 0.24635 - reactivity: 0.22838 - deg_Mg_pH10: 0.28011 - deg_Mg_50C: 0.23055
# Epoch 28/300   -   loss: 0.25430 - val_loss: 0.25242 - val_clean_loss: 0.24275 - val_aug_loss: 0.24248 - reactivity: 0.22346 - deg_Mg_pH10: 0.27504 - deg_Mg_50C: 0.22895
# Epoch 29/300   -   loss: 0.25430 - val_loss: 0.25618 - val_clean_loss: 0.24742 - val_aug_loss: 0.24738 - reactivity: 0.22982 - deg_Mg_pH10: 0.27813 - deg_Mg_50C: 0.23420
# Epoch 30/300   -   loss: 0.25306 - val_loss: 0.24863 - val_clean_loss: 0.23997 - val_aug_loss: 0.23971 - reactivity: 0.22101 - deg_Mg_pH10: 0.27190 - deg_Mg_50C: 0.22623
# Epoch 31/300   -   loss: 0.25085 - val_loss: 0.24532 - val_clean_loss: 0.23711 - val_aug_loss: 0.23686 - reactivity: 0.22016 - deg_Mg_pH10: 0.26768 - deg_Mg_50C: 0.22276
# Epoch 32/300   -   loss: 0.24908 - val_loss: 0.24499 - val_clean_loss: 0.23690 - val_aug_loss: 0.23680 - reactivity: 0.21968 - deg_Mg_pH10: 0.26966 - deg_Mg_50C: 0.22107
# Epoch 33/300   -   loss: 0.24532 - val_loss: 0.25072 - val_clean_loss: 0.24267 - val_aug_loss: 0.24210 - reactivity: 0.22118 - deg_Mg_pH10: 0.27966 - deg_Mg_50C: 0.22547
# Epoch 34/300   -   loss: 0.24387 - val_loss: 0.24065 - val_clean_loss: 0.23213 - val_aug_loss: 0.23195 - reactivity: 0.21528 - deg_Mg_pH10: 0.26289 - deg_Mg_50C: 0.21770
# Epoch 35/300   -   loss: 0.24415 - val_loss: 0.24543 - val_clean_loss: 0.23623 - val_aug_loss: 0.23609 - reactivity: 0.21945 - deg_Mg_pH10: 0.26684 - deg_Mg_50C: 0.22200
# Epoch 36/300   -   loss: 0.24127 - val_loss: 0.23953 - val_clean_loss: 0.23172 - val_aug_loss: 0.23145 - reactivity: 0.21518 - deg_Mg_pH10: 0.26196 - deg_Mg_50C: 0.21719
# Epoch 37/300   -   loss: 0.23804 - val_loss: 0.24418 - val_clean_loss: 0.23470 - val_aug_loss: 0.23455 - reactivity: 0.21571 - deg_Mg_pH10: 0.26539 - deg_Mg_50C: 0.22255
# Epoch 38/300   -   loss: 0.23714 - val_loss: 0.23703 - val_clean_loss: 0.22841 - val_aug_loss: 0.22828 - reactivity: 0.21143 - deg_Mg_pH10: 0.26000 - deg_Mg_50C: 0.21341
# Epoch 39/300   -   loss: 0.23672 - val_loss: 0.26826 - val_clean_loss: 0.25675 - val_aug_loss: 0.25555 - reactivity: 0.23335 - deg_Mg_pH10: 0.28774 - deg_Mg_50C: 0.24558
# Epoch 40/300   -   loss: 0.23800 - val_loss: 0.24011 - val_clean_loss: 0.23204 - val_aug_loss: 0.23170 - reactivity: 0.21737 - deg_Mg_pH10: 0.26105 - deg_Mg_50C: 0.21666
# Epoch 41/300   -   loss: 0.23196 - val_loss: 0.24061 - val_clean_loss: 0.23231 - val_aug_loss: 0.23201 - reactivity: 0.21245 - deg_Mg_pH10: 0.26678 - deg_Mg_50C: 0.21680
# Epoch 42/300   -   loss: 0.23010 - val_loss: 0.23886 - val_clean_loss: 0.22985 - val_aug_loss: 0.22939 - reactivity: 0.21222 - deg_Mg_pH10: 0.26004 - deg_Mg_50C: 0.21590
# Epoch 43/300   -   loss: 0.23007 - val_loss: 0.23962 - val_clean_loss: 0.22959 - val_aug_loss: 0.22935 - reactivity: 0.21129 - deg_Mg_pH10: 0.25885 - deg_Mg_50C: 0.21792
# Epoch 44/300   -   loss: 0.22901 - val_loss: 0.23610 - val_clean_loss: 0.22742 - val_aug_loss: 0.22724 - reactivity: 0.21064 - deg_Mg_pH10: 0.25735 - deg_Mg_50C: 0.21373
# Epoch 45/300   -   loss: 0.22747 - val_loss: 0.24235 - val_clean_loss: 0.23348 - val_aug_loss: 0.23296 - reactivity: 0.21822 - deg_Mg_pH10: 0.26322 - deg_Mg_50C: 0.21744
# Epoch 46/300   -   loss: 0.22626 - val_loss: 0.23178 - val_clean_loss: 0.22359 - val_aug_loss: 0.22323 - reactivity: 0.20769 - deg_Mg_pH10: 0.25252 - deg_Mg_50C: 0.20949
# Epoch 47/300   -   loss: 0.22242 - val_loss: 0.23642 - val_clean_loss: 0.22726 - val_aug_loss: 0.22679 - reactivity: 0.21073 - deg_Mg_pH10: 0.25745 - deg_Mg_50C: 0.21221
# Epoch 48/300   -   loss: 0.22279 - val_loss: 0.22977 - val_clean_loss: 0.22163 - val_aug_loss: 0.22139 - reactivity: 0.20734 - deg_Mg_pH10: 0.24980 - deg_Mg_50C: 0.20702
# Epoch 49/300   -   loss: 0.22050 - val_loss: 0.23585 - val_clean_loss: 0.22714 - val_aug_loss: 0.22681 - reactivity: 0.20937 - deg_Mg_pH10: 0.25664 - deg_Mg_50C: 0.21441
# Epoch 50/300   -   loss: 0.22076 - val_loss: 0.23063 - val_clean_loss: 0.22225 - val_aug_loss: 0.22202 - reactivity: 0.20579 - deg_Mg_pH10: 0.25156 - deg_Mg_50C: 0.20872
# Epoch 51/300   -   loss: 0.21981 - val_loss: 0.23383 - val_clean_loss: 0.22492 - val_aug_loss: 0.22445 - reactivity: 0.20812 - deg_Mg_pH10: 0.25430 - deg_Mg_50C: 0.21094
# Epoch 52/300   -   loss: 0.21881 - val_loss: 0.23114 - val_clean_loss: 0.22209 - val_aug_loss: 0.22176 - reactivity: 0.20518 - deg_Mg_pH10: 0.25126 - deg_Mg_50C: 0.20884
# Epoch 53/300   -   loss: 0.21634 - val_loss: 0.23250 - val_clean_loss: 0.22390 - val_aug_loss: 0.22344 - reactivity: 0.20628 - deg_Mg_pH10: 0.25651 - deg_Mg_50C: 0.20754
# Epoch 54/300   -   loss: 0.21725 - val_loss: 0.22984 - val_clean_loss: 0.22168 - val_aug_loss: 0.22121 - reactivity: 0.20607 - deg_Mg_pH10: 0.25006 - deg_Mg_50C: 0.20749
# Epoch 55/300   -   loss: 0.21618 - val_loss: 0.23489 - val_clean_loss: 0.22590 - val_aug_loss: 0.22560 - reactivity: 0.21190 - deg_Mg_pH10: 0.25473 - deg_Mg_50C: 0.21017
# Epoch 56/300   -   loss: 0.21383 - val_loss: 0.23273 - val_clean_loss: 0.22407 - val_aug_loss: 0.22383 - reactivity: 0.20767 - deg_Mg_pH10: 0.25437 - deg_Mg_50C: 0.20946
# Epoch 57/300   -   loss: 0.21287 - val_loss: 0.23479 - val_clean_loss: 0.22625 - val_aug_loss: 0.22603 - reactivity: 0.21023 - deg_Mg_pH10: 0.25522 - deg_Mg_50C: 0.21264
# Epoch 58/300   -   loss: 0.21171 - val_loss: 0.22696 - val_clean_loss: 0.21869 - val_aug_loss: 0.21844 - reactivity: 0.20375 - deg_Mg_pH10: 0.24801 - deg_Mg_50C: 0.20356
# Epoch 59/300   -   loss: 0.21180 - val_loss: 0.23488 - val_clean_loss: 0.22704 - val_aug_loss: 0.22668 - reactivity: 0.21066 - deg_Mg_pH10: 0.25721 - deg_Mg_50C: 0.21218
# Epoch 60/300   -   loss: 0.21029 - val_loss: 0.22634 - val_clean_loss: 0.21902 - val_aug_loss: 0.21869 - reactivity: 0.20454 - deg_Mg_pH10: 0.24886 - deg_Mg_50C: 0.20268
# Epoch 61/300   -   loss: 0.20921 - val_loss: 0.23240 - val_clean_loss: 0.22346 - val_aug_loss: 0.22324 - reactivity: 0.20550 - deg_Mg_pH10: 0.25526 - deg_Mg_50C: 0.20896
# Epoch 62/300   -   loss: 0.20844 - val_loss: 0.22631 - val_clean_loss: 0.21870 - val_aug_loss: 0.21827 - reactivity: 0.20273 - deg_Mg_pH10: 0.24871 - deg_Mg_50C: 0.20338
# Epoch 63/300   -   loss: 0.20544 - val_loss: 0.22765 - val_clean_loss: 0.21866 - val_aug_loss: 0.21808 - reactivity: 0.20423 - deg_Mg_pH10: 0.24738 - deg_Mg_50C: 0.20264
# Epoch 64/300   -   loss: 0.20454 - val_loss: 0.22701 - val_clean_loss: 0.21814 - val_aug_loss: 0.21769 - reactivity: 0.20061 - deg_Mg_pH10: 0.24778 - deg_Mg_50C: 0.20469
# Epoch 65/300   -   loss: 0.20317 - val_loss: 0.22706 - val_clean_loss: 0.21787 - val_aug_loss: 0.21765 - reactivity: 0.19895 - deg_Mg_pH10: 0.24955 - deg_Mg_50C: 0.20446
# Epoch 66/300   -   loss: 0.20340 - val_loss: 0.22786 - val_clean_loss: 0.21970 - val_aug_loss: 0.21918 - reactivity: 0.20281 - deg_Mg_pH10: 0.25006 - deg_Mg_50C: 0.20467
# Epoch 67/300   -   loss: 0.20202 - val_loss: 0.23222 - val_clean_loss: 0.22375 - val_aug_loss: 0.22331 - reactivity: 0.20640 - deg_Mg_pH10: 0.25548 - deg_Mg_50C: 0.20807
# Epoch 68/300   -   loss: 0.20381 - val_loss: 0.22520 - val_clean_loss: 0.21727 - val_aug_loss: 0.21685 - reactivity: 0.20071 - deg_Mg_pH10: 0.24659 - deg_Mg_50C: 0.20326
# Epoch 69/300   -   loss: 0.20422 - val_loss: 0.22917 - val_clean_loss: 0.21983 - val_aug_loss: 0.21951 - reactivity: 0.20463 - deg_Mg_pH10: 0.24784 - deg_Mg_50C: 0.20605
# Epoch 70/300   -   loss: 0.20111 - val_loss: 0.22249 - val_clean_loss: 0.21498 - val_aug_loss: 0.21459 - reactivity: 0.19968 - deg_Mg_pH10: 0.24410 - deg_Mg_50C: 0.19998
# Epoch 71/300   -   loss: 0.19842 - val_loss: 0.22468 - val_clean_loss: 0.21628 - val_aug_loss: 0.21591 - reactivity: 0.19894 - deg_Mg_pH10: 0.24732 - deg_Mg_50C: 0.20147
# Epoch 72/300   -   loss: 0.19851 - val_loss: 0.22153 - val_clean_loss: 0.21404 - val_aug_loss: 0.21359 - reactivity: 0.19910 - deg_Mg_pH10: 0.24342 - deg_Mg_50C: 0.19825
# Epoch 73/300   -   loss: 0.19784 - val_loss: 0.23108 - val_clean_loss: 0.22209 - val_aug_loss: 0.22184 - reactivity: 0.20522 - deg_Mg_pH10: 0.25153 - deg_Mg_50C: 0.20876
# Epoch 74/300   -   loss: 0.19701 - val_loss: 0.22309 - val_clean_loss: 0.21442 - val_aug_loss: 0.21405 - reactivity: 0.19961 - deg_Mg_pH10: 0.24346 - deg_Mg_50C: 0.19909
# Epoch 75/300   -   loss: 0.19776 - val_loss: 0.22648 - val_clean_loss: 0.21742 - val_aug_loss: 0.21699 - reactivity: 0.20015 - deg_Mg_pH10: 0.24788 - deg_Mg_50C: 0.20294
# Epoch 76/300   -   loss: 0.19566 - val_loss: 0.22183 - val_clean_loss: 0.21357 - val_aug_loss: 0.21306 - reactivity: 0.19690 - deg_Mg_pH10: 0.24298 - deg_Mg_50C: 0.19931
# Epoch 77/300   -   loss: 0.19305 - val_loss: 0.22423 - val_clean_loss: 0.21500 - val_aug_loss: 0.21450 - reactivity: 0.19872 - deg_Mg_pH10: 0.24450 - deg_Mg_50C: 0.20029
# Epoch 78/300   -   loss: 0.19366 - val_loss: 0.22230 - val_clean_loss: 0.21392 - val_aug_loss: 0.21345 - reactivity: 0.19695 - deg_Mg_pH10: 0.24353 - deg_Mg_50C: 0.19988
# Epoch 79/300   -   loss: 0.19226 - val_loss: 0.22887 - val_clean_loss: 0.21894 - val_aug_loss: 0.21848 - reactivity: 0.20160 - deg_Mg_pH10: 0.24924 - deg_Mg_50C: 0.20462
# Epoch 80/300   -   loss: 0.19145 - val_loss: 0.22021 - val_clean_loss: 0.21217 - val_aug_loss: 0.21179 - reactivity: 0.19668 - deg_Mg_pH10: 0.24135 - deg_Mg_50C: 0.19733
# Epoch 81/300   -   loss: 0.19165 - val_loss: 0.22857 - val_clean_loss: 0.22146 - val_aug_loss: 0.22090 - reactivity: 0.20308 - deg_Mg_pH10: 0.25343 - deg_Mg_50C: 0.20618
# Epoch 82/300   -   loss: 0.19104 - val_loss: 0.22148 - val_clean_loss: 0.21434 - val_aug_loss: 0.21407 - reactivity: 0.19785 - deg_Mg_pH10: 0.24411 - deg_Mg_50C: 0.20024
# Epoch 83/300   -   loss: 0.18903 - val_loss: 0.22610 - val_clean_loss: 0.21769 - val_aug_loss: 0.21730 - reactivity: 0.19877 - deg_Mg_pH10: 0.24608 - deg_Mg_50C: 0.20707
# Epoch 84/300   -   loss: 0.18945 - val_loss: 0.22119 - val_clean_loss: 0.21264 - val_aug_loss: 0.21232 - reactivity: 0.19701 - deg_Mg_pH10: 0.24213 - deg_Mg_50C: 0.19782
# Epoch 85/300   -   loss: 0.18755 - val_loss: 0.22693 - val_clean_loss: 0.21808 - val_aug_loss: 0.21763 - reactivity: 0.20442 - deg_Mg_pH10: 0.24672 - deg_Mg_50C: 0.20175
# Epoch 86/300   -   loss: 0.18791 - val_loss: 0.21907 - val_clean_loss: 0.21055 - val_aug_loss: 0.21020 - reactivity: 0.19477 - deg_Mg_pH10: 0.24045 - deg_Mg_50C: 0.19539
# Epoch 87/300   -   loss: 0.18729 - val_loss: 0.22366 - val_clean_loss: 0.21471 - val_aug_loss: 0.21443 - reactivity: 0.19907 - deg_Mg_pH10: 0.24352 - deg_Mg_50C: 0.20071
# Epoch 88/300   -   loss: 0.18854 - val_loss: 0.21985 - val_clean_loss: 0.21164 - val_aug_loss: 0.21134 - reactivity: 0.19717 - deg_Mg_pH10: 0.24016 - deg_Mg_50C: 0.19669
# Epoch 89/300   -   loss: 0.18751 - val_loss: 0.22823 - val_clean_loss: 0.22049 - val_aug_loss: 0.22021 - reactivity: 0.20291 - deg_Mg_pH10: 0.25233 - deg_Mg_50C: 0.20540
# Epoch 90/300   -   loss: 0.18726 - val_loss: 0.21948 - val_clean_loss: 0.21203 - val_aug_loss: 0.21172 - reactivity: 0.19632 - deg_Mg_pH10: 0.24138 - deg_Mg_50C: 0.19746
# Epoch 91/300   -   loss: 0.18550 - val_loss: 0.22378 - val_clean_loss: 0.21660 - val_aug_loss: 0.21628 - reactivity: 0.20244 - deg_Mg_pH10: 0.24520 - deg_Mg_50C: 0.20120
# Epoch 92/300   -   loss: 0.18427 - val_loss: 0.21844 - val_clean_loss: 0.20991 - val_aug_loss: 0.20979 - reactivity: 0.19484 - deg_Mg_pH10: 0.23906 - deg_Mg_50C: 0.19546
# Epoch 93/300   -   loss: 0.18319 - val_loss: 0.22184 - val_clean_loss: 0.21321 - val_aug_loss: 0.21294 - reactivity: 0.19677 - deg_Mg_pH10: 0.24212 - deg_Mg_50C: 0.19994
# Epoch 94/300   -   loss: 0.18705 - val_loss: 0.22027 - val_clean_loss: 0.21148 - val_aug_loss: 0.21122 - reactivity: 0.19604 - deg_Mg_pH10: 0.24031 - deg_Mg_50C: 0.19730
# Epoch 95/300   -   loss: 0.18313 - val_loss: 0.22636 - val_clean_loss: 0.21827 - val_aug_loss: 0.21800 - reactivity: 0.20558 - deg_Mg_pH10: 0.24504 - deg_Mg_50C: 0.20339
# Epoch 96/300   -   loss: 0.18326 - val_loss: 0.21943 - val_clean_loss: 0.21159 - val_aug_loss: 0.21123 - reactivity: 0.19581 - deg_Mg_pH10: 0.24073 - deg_Mg_50C: 0.19714
# Epoch 97/300   -   loss: 0.18232 - val_loss: 0.22180 - val_clean_loss: 0.21260 - val_aug_loss: 0.21234 - reactivity: 0.19652 - deg_Mg_pH10: 0.24287 - deg_Mg_50C: 0.19764
# Epoch 98/300   -   loss: 0.18226 - val_loss: 0.21836 - val_clean_loss: 0.20931 - val_aug_loss: 0.20904 - reactivity: 0.19362 - deg_Mg_pH10: 0.23925 - deg_Mg_50C: 0.19427
# Epoch 99/300   -   loss: 0.18117 - val_loss: 0.22073 - val_clean_loss: 0.21220 - val_aug_loss: 0.21196 - reactivity: 0.19775 - deg_Mg_pH10: 0.24147 - deg_Mg_50C: 0.19665
# Epoch 100/300   -   loss: 0.18103 - val_loss: 0.22165 - val_clean_loss: 0.21260 - val_aug_loss: 0.21219 - reactivity: 0.19712 - deg_Mg_pH10: 0.24161 - deg_Mg_50C: 0.19783
# Epoch 101/300   -   loss: 0.17586 - val_loss: 0.21823 - val_clean_loss: 0.20913 - val_aug_loss: 0.20882 - reactivity: 0.19399 - deg_Mg_pH10: 0.23922 - deg_Mg_50C: 0.19324
# Epoch 102/300   -   loss: 0.17469 - val_loss: 0.21606 - val_clean_loss: 0.20782 - val_aug_loss: 0.20760 - reactivity: 0.19318 - deg_Mg_pH10: 0.23706 - deg_Mg_50C: 0.19256
# Epoch 103/300   -   loss: 0.17289 - val_loss: 0.21694 - val_clean_loss: 0.20823 - val_aug_loss: 0.20799 - reactivity: 0.19321 - deg_Mg_pH10: 0.23765 - deg_Mg_50C: 0.19312
# Epoch 104/300   -   loss: 0.17249 - val_loss: 0.21606 - val_clean_loss: 0.20769 - val_aug_loss: 0.20744 - reactivity: 0.19256 - deg_Mg_pH10: 0.23697 - deg_Mg_50C: 0.19279
# Epoch 105/300   -   loss: 0.17215 - val_loss: 0.21584 - val_clean_loss: 0.20748 - val_aug_loss: 0.20725 - reactivity: 0.19273 - deg_Mg_pH10: 0.23693 - deg_Mg_50C: 0.19211
# Epoch 106/300   -   loss: 0.17158 - val_loss: 0.21630 - val_clean_loss: 0.20781 - val_aug_loss: 0.20755 - reactivity: 0.19306 - deg_Mg_pH10: 0.23696 - deg_Mg_50C: 0.19264
# Epoch 107/300   -   loss: 0.17039 - val_loss: 0.21851 - val_clean_loss: 0.20930 - val_aug_loss: 0.20901 - reactivity: 0.19480 - deg_Mg_pH10: 0.23856 - deg_Mg_50C: 0.19368
# Epoch 108/300   -   loss: 0.17029 - val_loss: 0.21557 - val_clean_loss: 0.20670 - val_aug_loss: 0.20649 - reactivity: 0.19211 - deg_Mg_pH10: 0.23609 - deg_Mg_50C: 0.19128
# Epoch 109/300   -   loss: 0.16904 - val_loss: 0.21587 - val_clean_loss: 0.20768 - val_aug_loss: 0.20750 - reactivity: 0.19445 - deg_Mg_pH10: 0.23590 - deg_Mg_50C: 0.19214
# Epoch 110/300   -   loss: 0.16937 - val_loss: 0.21565 - val_clean_loss: 0.20715 - val_aug_loss: 0.20690 - reactivity: 0.19315 - deg_Mg_pH10: 0.23597 - deg_Mg_50C: 0.19159
# Epoch 111/300   -   loss: 0.16881 - val_loss: 0.21737 - val_clean_loss: 0.20907 - val_aug_loss: 0.20878 - reactivity: 0.19410 - deg_Mg_pH10: 0.23813 - deg_Mg_50C: 0.19411
# Epoch 112/300   -   loss: 0.16853 - val_loss: 0.21628 - val_clean_loss: 0.20738 - val_aug_loss: 0.20711 - reactivity: 0.19295 - deg_Mg_pH10: 0.23616 - deg_Mg_50C: 0.19221
# Epoch 113/300   -   loss: 0.16831 - val_loss: 0.21861 - val_clean_loss: 0.20994 - val_aug_loss: 0.20958 - reactivity: 0.19468 - deg_Mg_pH10: 0.24036 - deg_Mg_50C: 0.19371
# Epoch 114/300   -   loss: 0.16828 - val_loss: 0.21661 - val_clean_loss: 0.20808 - val_aug_loss: 0.20776 - reactivity: 0.19372 - deg_Mg_pH10: 0.23709 - deg_Mg_50C: 0.19248
# Epoch 115/300   -   loss: 0.16737 - val_loss: 0.21623 - val_clean_loss: 0.20815 - val_aug_loss: 0.20784 - reactivity: 0.19321 - deg_Mg_pH10: 0.23751 - deg_Mg_50C: 0.19281
# Epoch 116/300   -   loss: 0.16835 - val_loss: 0.21428 - val_clean_loss: 0.20630 - val_aug_loss: 0.20604 - reactivity: 0.19157 - deg_Mg_pH10: 0.23565 - deg_Mg_50C: 0.19089
# Epoch 117/300   -   loss: 0.16794 - val_loss: 0.21653 - val_clean_loss: 0.20815 - val_aug_loss: 0.20782 - reactivity: 0.19341 - deg_Mg_pH10: 0.23714 - deg_Mg_50C: 0.19292
# Epoch 118/300   -   loss: 0.16691 - val_loss: 0.21698 - val_clean_loss: 0.20857 - val_aug_loss: 0.20825 - reactivity: 0.19355 - deg_Mg_pH10: 0.23733 - deg_Mg_50C: 0.19388
# Epoch 119/300   -   loss: 0.16583 - val_loss: 0.21803 - val_clean_loss: 0.20801 - val_aug_loss: 0.20773 - reactivity: 0.19208 - deg_Mg_pH10: 0.23712 - deg_Mg_50C: 0.19400
# Epoch 120/300   -   loss: 0.16630 - val_loss: 0.21612 - val_clean_loss: 0.20760 - val_aug_loss: 0.20731 - reactivity: 0.19179 - deg_Mg_pH10: 0.23753 - deg_Mg_50C: 0.19261
# Epoch 121/300   -   loss: 0.16583 - val_loss: 0.21878 - val_clean_loss: 0.20988 - val_aug_loss: 0.20961 - reactivity: 0.19386 - deg_Mg_pH10: 0.24044 - deg_Mg_50C: 0.19454
# Epoch 122/300   -   loss: 0.16725 - val_loss: 0.21662 - val_clean_loss: 0.20813 - val_aug_loss: 0.20791 - reactivity: 0.19378 - deg_Mg_pH10: 0.23700 - deg_Mg_50C: 0.19297
# Epoch 123/300   -   loss: 0.16542 - val_loss: 0.21809 - val_clean_loss: 0.20866 - val_aug_loss: 0.20845 - reactivity: 0.19270 - deg_Mg_pH10: 0.23763 - deg_Mg_50C: 0.19502
# Epoch 124/300   -   loss: 0.16547 - val_loss: 0.21582 - val_clean_loss: 0.20746 - val_aug_loss: 0.20717 - reactivity: 0.19245 - deg_Mg_pH10: 0.23675 - deg_Mg_50C: 0.19231
# Epoch 125/300   -   loss: 0.16638 - val_loss: 0.22002 - val_clean_loss: 0.21165 - val_aug_loss: 0.21127 - reactivity: 0.19750 - deg_Mg_pH10: 0.24059 - deg_Mg_50C: 0.19573
# Epoch 126/300   -   loss: 0.16538 - val_loss: 0.21612 - val_clean_loss: 0.20810 - val_aug_loss: 0.20779 - reactivity: 0.19306 - deg_Mg_pH10: 0.23732 - deg_Mg_50C: 0.19299
# Epoch 127/300   -   loss: 0.16461 - val_loss: 0.21637 - val_clean_loss: 0.20740 - val_aug_loss: 0.20709 - reactivity: 0.19213 - deg_Mg_pH10: 0.23653 - deg_Mg_50C: 0.19261
# Epoch 128/300   -   loss: 0.16311 - val_loss: 0.21544 - val_clean_loss: 0.20707 - val_aug_loss: 0.20677 - reactivity: 0.19215 - deg_Mg_pH10: 0.23599 - deg_Mg_50C: 0.19216
# Epoch 129/300   -   loss: 0.16322 - val_loss: 0.22552 - val_clean_loss: 0.21581 - val_aug_loss: 0.21534 - reactivity: 0.20204 - deg_Mg_pH10: 0.24330 - deg_Mg_50C: 0.20070
# Epoch 130/300   -   loss: 0.16373 - val_loss: 0.21589 - val_clean_loss: 0.20729 - val_aug_loss: 0.20704 - reactivity: 0.19296 - deg_Mg_pH10: 0.23613 - deg_Mg_50C: 0.19202
# Epoch 131/300   -   loss: 0.16298 - val_loss: 0.21610 - val_clean_loss: 0.20706 - val_aug_loss: 0.20690 - reactivity: 0.19122 - deg_Mg_pH10: 0.23632 - deg_Mg_50C: 0.19314
# Epoch 132/300   -   loss: 0.16318 - val_loss: 0.21627 - val_clean_loss: 0.20781 - val_aug_loss: 0.20759 - reactivity: 0.19247 - deg_Mg_pH10: 0.23712 - deg_Mg_50C: 0.19318
# Epoch 133/300   -   loss: 0.16240 - val_loss: 0.21718 - val_clean_loss: 0.20819 - val_aug_loss: 0.20803 - reactivity: 0.19234 - deg_Mg_pH10: 0.23973 - deg_Mg_50C: 0.19203
# Epoch 134/300   -   loss: 0.16209 - val_loss: 0.21668 - val_clean_loss: 0.20841 - val_aug_loss: 0.20821 - reactivity: 0.19330 - deg_Mg_pH10: 0.23751 - deg_Mg_50C: 0.19381
# Epoch 135/300   -   loss: 0.16191 - val_loss: 0.21622 - val_clean_loss: 0.20769 - val_aug_loss: 0.20745 - reactivity: 0.19173 - deg_Mg_pH10: 0.23781 - deg_Mg_50C: 0.19281
# Epoch 136/300   -   loss: 0.16232 - val_loss: 0.21571 - val_clean_loss: 0.20657 - val_aug_loss: 0.20638 - reactivity: 0.19146 - deg_Mg_pH10: 0.23591 - deg_Mg_50C: 0.19178
# Epoch 137/300   -   loss: 0.16161 - val_loss: 0.21576 - val_clean_loss: 0.20719 - val_aug_loss: 0.20703 - reactivity: 0.19183 - deg_Mg_pH10: 0.23626 - deg_Mg_50C: 0.19299
# Epoch 138/300   -   loss: 0.16117 - val_loss: 0.21460 - val_clean_loss: 0.20613 - val_aug_loss: 0.20595 - reactivity: 0.19075 - deg_Mg_pH10: 0.23584 - deg_Mg_50C: 0.19127
# Epoch 139/300   -   loss: 0.16147 - val_loss: 0.22090 - val_clean_loss: 0.21327 - val_aug_loss: 0.21296 - reactivity: 0.19745 - deg_Mg_pH10: 0.24337 - deg_Mg_50C: 0.19806
# Epoch 140/300   -   loss: 0.16138 - val_loss: 0.21559 - val_clean_loss: 0.20687 - val_aug_loss: 0.20660 - reactivity: 0.19078 - deg_Mg_pH10: 0.23666 - deg_Mg_50C: 0.19235
# Epoch 141/300   -   loss: 0.16064 - val_loss: 0.21638 - val_clean_loss: 0.20794 - val_aug_loss: 0.20767 - reactivity: 0.19202 - deg_Mg_pH10: 0.23527 - deg_Mg_50C: 0.19571
# Epoch 142/300   -   loss: 0.16011 - val_loss: 0.21525 - val_clean_loss: 0.20622 - val_aug_loss: 0.20601 - reactivity: 0.19062 - deg_Mg_pH10: 0.23498 - deg_Mg_50C: 0.19244
# Epoch 143/300   -   loss: 0.16003 - val_loss: 0.21754 - val_clean_loss: 0.20893 - val_aug_loss: 0.20873 - reactivity: 0.19320 - deg_Mg_pH10: 0.23825 - deg_Mg_50C: 0.19475
# Epoch 144/300   -   loss: 0.15975 - val_loss: 0.21451 - val_clean_loss: 0.20581 - val_aug_loss: 0.20560 - reactivity: 0.19076 - deg_Mg_pH10: 0.23448 - deg_Mg_50C: 0.19155
# Epoch 145/300   -   loss: 0.15879 - val_loss: 0.21528 - val_clean_loss: 0.20698 - val_aug_loss: 0.20671 - reactivity: 0.19080 - deg_Mg_pH10: 0.23524 - deg_Mg_50C: 0.19409
# Epoch 146/300   -   loss: 0.15935 - val_loss: 0.21409 - val_clean_loss: 0.20522 - val_aug_loss: 0.20506 - reactivity: 0.18976 - deg_Mg_pH10: 0.23475 - deg_Mg_50C: 0.19067
# Epoch 147/300   -   loss: 0.15893 - val_loss: 0.21745 - val_clean_loss: 0.20904 - val_aug_loss: 0.20877 - reactivity: 0.19310 - deg_Mg_pH10: 0.23893 - deg_Mg_50C: 0.19428
# Epoch 148/300   -   loss: 0.15927 - val_loss: 0.21506 - val_clean_loss: 0.20645 - val_aug_loss: 0.20618 - reactivity: 0.19141 - deg_Mg_pH10: 0.23525 - deg_Mg_50C: 0.19186
# Epoch 149/300   -   loss: 0.15839 - val_loss: 0.21586 - val_clean_loss: 0.20657 - val_aug_loss: 0.20641 - reactivity: 0.19074 - deg_Mg_pH10: 0.23601 - deg_Mg_50C: 0.19249
# Epoch 150/300   -   loss: 0.15915 - val_loss: 0.21424 - val_clean_loss: 0.20505 - val_aug_loss: 0.20484 - reactivity: 0.18987 - deg_Mg_pH10: 0.23405 - deg_Mg_50C: 0.19061
# Epoch 151/300   -   loss: 0.15873 - val_loss: 0.21616 - val_clean_loss: 0.20740 - val_aug_loss: 0.20722 - reactivity: 0.19298 - deg_Mg_pH10: 0.23544 - deg_Mg_50C: 0.19323
# Epoch 152/300   -   loss: 0.15867 - val_loss: 0.21448 - val_clean_loss: 0.20563 - val_aug_loss: 0.20540 - reactivity: 0.19007 - deg_Mg_pH10: 0.23550 - deg_Mg_50C: 0.19062
# Epoch 153/300   -   loss: 0.15790 - val_loss: 0.21657 - val_clean_loss: 0.20841 - val_aug_loss: 0.20814 - reactivity: 0.19394 - deg_Mg_pH10: 0.23775 - deg_Mg_50C: 0.19274
# Epoch 154/300   -   loss: 0.15865 - val_loss: 0.21419 - val_clean_loss: 0.20562 - val_aug_loss: 0.20537 - reactivity: 0.19103 - deg_Mg_pH10: 0.23499 - deg_Mg_50C: 0.19008
# Epoch 155/300   -   loss: 0.15817 - val_loss: 0.21597 - val_clean_loss: 0.20774 - val_aug_loss: 0.20743 - reactivity: 0.19167 - deg_Mg_pH10: 0.23649 - deg_Mg_50C: 0.19414
# Epoch 156/300   -   loss: 0.15793 - val_loss: 0.21527 - val_clean_loss: 0.20687 - val_aug_loss: 0.20664 - reactivity: 0.19119 - deg_Mg_pH10: 0.23606 - deg_Mg_50C: 0.19266
# Epoch 157/300   -   loss: 0.15623 - val_loss: 0.21739 - val_clean_loss: 0.20879 - val_aug_loss: 0.20854 - reactivity: 0.19416 - deg_Mg_pH10: 0.23746 - deg_Mg_50C: 0.19402
# Epoch 158/300   -   loss: 0.15686 - val_loss: 0.21406 - val_clean_loss: 0.20566 - val_aug_loss: 0.20546 - reactivity: 0.19011 - deg_Mg_pH10: 0.23476 - deg_Mg_50C: 0.19151
# Epoch 159/300   -   loss: 0.15681 - val_loss: 0.21821 - val_clean_loss: 0.20910 - val_aug_loss: 0.20886 - reactivity: 0.19401 - deg_Mg_pH10: 0.23723 - deg_Mg_50C: 0.19534
# Epoch 160/300   -   loss: 0.15661 - val_loss: 0.21437 - val_clean_loss: 0.20590 - val_aug_loss: 0.20573 - reactivity: 0.19114 - deg_Mg_pH10: 0.23532 - deg_Mg_50C: 0.19074
# Epoch 161/300   -   loss: 0.15681 - val_loss: 0.21582 - val_clean_loss: 0.20679 - val_aug_loss: 0.20662 - reactivity: 0.19146 - deg_Mg_pH10: 0.23514 - deg_Mg_50C: 0.19326
# Epoch 162/300   -   loss: 0.15608 - val_loss: 0.21415 - val_clean_loss: 0.20561 - val_aug_loss: 0.20535 - reactivity: 0.19069 - deg_Mg_pH10: 0.23419 - deg_Mg_50C: 0.19118
# Epoch 163/300   -   loss: 0.15538 - val_loss: 0.21602 - val_clean_loss: 0.20720 - val_aug_loss: 0.20705 - reactivity: 0.19220 - deg_Mg_pH10: 0.23620 - deg_Mg_50C: 0.19274
# Epoch 164/300   -   loss: 0.15626 - val_loss: 0.21350 - val_clean_loss: 0.20561 - val_aug_loss: 0.20542 - reactivity: 0.19208 - deg_Mg_pH10: 0.23419 - deg_Mg_50C: 0.18999
# Epoch 165/300   -   loss: 0.15563 - val_loss: 0.21677 - val_clean_loss: 0.20869 - val_aug_loss: 0.20842 - reactivity: 0.19388 - deg_Mg_pH10: 0.23673 - deg_Mg_50C: 0.19465
# Epoch 166/300   -   loss: 0.15548 - val_loss: 0.21309 - val_clean_loss: 0.20456 - val_aug_loss: 0.20433 - reactivity: 0.18911 - deg_Mg_pH10: 0.23459 - deg_Mg_50C: 0.18929
# Epoch 167/300   -   loss: 0.15376 - val_loss: 0.21490 - val_clean_loss: 0.20614 - val_aug_loss: 0.20595 - reactivity: 0.19132 - deg_Mg_pH10: 0.23539 - deg_Mg_50C: 0.19114
# Epoch 168/300   -   loss: 0.15443 - val_loss: 0.21428 - val_clean_loss: 0.20594 - val_aug_loss: 0.20564 - reactivity: 0.19134 - deg_Mg_pH10: 0.23505 - deg_Mg_50C: 0.19055
# Epoch 169/300   -   loss: 0.15405 - val_loss: 0.21544 - val_clean_loss: 0.20754 - val_aug_loss: 0.20730 - reactivity: 0.19157 - deg_Mg_pH10: 0.23591 - deg_Mg_50C: 0.19442
# Epoch 170/300   -   loss: 0.15420 - val_loss: 0.21479 - val_clean_loss: 0.20667 - val_aug_loss: 0.20642 - reactivity: 0.19151 - deg_Mg_pH10: 0.23580 - deg_Mg_50C: 0.19195
# Epoch 171/300   -   loss: 0.15416 - val_loss: 0.21449 - val_clean_loss: 0.20542 - val_aug_loss: 0.20515 - reactivity: 0.19095 - deg_Mg_pH10: 0.23454 - deg_Mg_50C: 0.18998
# Epoch 172/300   -   loss: 0.15364 - val_loss: 0.21419 - val_clean_loss: 0.20582 - val_aug_loss: 0.20554 - reactivity: 0.19090 - deg_Mg_pH10: 0.23478 - deg_Mg_50C: 0.19094
# Epoch 173/300   -   loss: 0.15310 - val_loss: 0.21445 - val_clean_loss: 0.20622 - val_aug_loss: 0.20593 - reactivity: 0.19035 - deg_Mg_pH10: 0.23537 - deg_Mg_50C: 0.19207
# Epoch 174/300   -   loss: 0.15334 - val_loss: 0.21441 - val_clean_loss: 0.20548 - val_aug_loss: 0.20518 - reactivity: 0.19147 - deg_Mg_pH10: 0.23411 - deg_Mg_50C: 0.18997
# Epoch 175/300   -   loss: 0.15318 - val_loss: 0.21512 - val_clean_loss: 0.20590 - val_aug_loss: 0.20562 - reactivity: 0.19127 - deg_Mg_pH10: 0.23520 - deg_Mg_50C: 0.19037
# Epoch 176/300   -   loss: 0.15262 - val_loss: 0.21435 - val_clean_loss: 0.20580 - val_aug_loss: 0.20549 - reactivity: 0.19025 - deg_Mg_pH10: 0.23521 - deg_Mg_50C: 0.19102
# Epoch 177/300   -   loss: 0.15225 - val_loss: 0.21486 - val_clean_loss: 0.20637 - val_aug_loss: 0.20606 - reactivity: 0.18952 - deg_Mg_pH10: 0.23634 - deg_Mg_50C: 0.19230
# Epoch 178/300   -   loss: 0.15262 - val_loss: 0.21382 - val_clean_loss: 0.20576 - val_aug_loss: 0.20547 - reactivity: 0.19026 - deg_Mg_pH10: 0.23536 - deg_Mg_50C: 0.19078
# Epoch 179/300   -   loss: 0.15209 - val_loss: 0.21474 - val_clean_loss: 0.20633 - val_aug_loss: 0.20606 - reactivity: 0.19151 - deg_Mg_pH10: 0.23539 - deg_Mg_50C: 0.19129
# Epoch 180/300   -   loss: 0.15223 - val_loss: 0.21477 - val_clean_loss: 0.20692 - val_aug_loss: 0.20659 - reactivity: 0.19136 - deg_Mg_pH10: 0.23621 - deg_Mg_50C: 0.19219
# Epoch 181/300   -   loss: 0.15189 - val_loss: 0.21773 - val_clean_loss: 0.20952 - val_aug_loss: 0.20922 - reactivity: 0.19345 - deg_Mg_pH10: 0.23796 - deg_Mg_50C: 0.19625
# Epoch 182/300   -   loss: 0.15155 - val_loss: 0.21338 - val_clean_loss: 0.20488 - val_aug_loss: 0.20465 - reactivity: 0.19026 - deg_Mg_pH10: 0.23410 - deg_Mg_50C: 0.18959
# Epoch 183/300   -   loss: 0.15063 - val_loss: 0.21667 - val_clean_loss: 0.20874 - val_aug_loss: 0.20838 - reactivity: 0.19272 - deg_Mg_pH10: 0.23870 - deg_Mg_50C: 0.19372
# Epoch 184/300   -   loss: 0.15176 - val_loss: 0.21455 - val_clean_loss: 0.20594 - val_aug_loss: 0.20560 - reactivity: 0.19101 - deg_Mg_pH10: 0.23466 - deg_Mg_50C: 0.19111
# Epoch 185/300   -   loss: 0.15081 - val_loss: 0.21473 - val_clean_loss: 0.20666 - val_aug_loss: 0.20644 - reactivity: 0.19124 - deg_Mg_pH10: 0.23625 - deg_Mg_50C: 0.19182
# Epoch 186/300   -   loss: 0.15128 - val_loss: 0.21539 - val_clean_loss: 0.20781 - val_aug_loss: 0.20739 - reactivity: 0.19242 - deg_Mg_pH10: 0.23686 - deg_Mg_50C: 0.19287
# Epoch 187/300   -   loss: 0.15009 - val_loss: 0.21683 - val_clean_loss: 0.20919 - val_aug_loss: 0.20887 - reactivity: 0.19536 - deg_Mg_pH10: 0.23895 - deg_Mg_50C: 0.19229
# Epoch 188/300   -   loss: 0.15091 - val_loss: 0.21408 - val_clean_loss: 0.20628 - val_aug_loss: 0.20600 - reactivity: 0.19125 - deg_Mg_pH10: 0.23566 - deg_Mg_50C: 0.19110
# Epoch 189/300   -   loss: 0.14979 - val_loss: 0.21562 - val_clean_loss: 0.20693 - val_aug_loss: 0.20672 - reactivity: 0.19082 - deg_Mg_pH10: 0.23674 - deg_Mg_50C: 0.19258
# Epoch 190/300   -   loss: 0.15082 - val_loss: 0.21418 - val_clean_loss: 0.20629 - val_aug_loss: 0.20602 - reactivity: 0.19087 - deg_Mg_pH10: 0.23508 - deg_Mg_50C: 0.19210
# Epoch 191/300   -   loss: 0.14997 - val_loss: 0.21696 - val_clean_loss: 0.20896 - val_aug_loss: 0.20864 - reactivity: 0.19580 - deg_Mg_pH10: 0.23751 - deg_Mg_50C: 0.19259
# Epoch 192/300   -   loss: 0.14979 - val_loss: 0.21391 - val_clean_loss: 0.20555 - val_aug_loss: 0.20536 - reactivity: 0.18993 - deg_Mg_pH10: 0.23551 - deg_Mg_50C: 0.19065
# Epoch 193/300   -   loss: 0.14928 - val_loss: 0.21465 - val_clean_loss: 0.20647 - val_aug_loss: 0.20624 - reactivity: 0.19162 - deg_Mg_pH10: 0.23562 - deg_Mg_50C: 0.19148
# Epoch 194/300   -   loss: 0.14887 - val_loss: 0.21371 - val_clean_loss: 0.20498 - val_aug_loss: 0.20480 - reactivity: 0.18980 - deg_Mg_pH10: 0.23527 - deg_Mg_50C: 0.18933
# Epoch 195/300   -   loss: 0.14978 - val_loss: 0.21536 - val_clean_loss: 0.20633 - val_aug_loss: 0.20609 - reactivity: 0.19015 - deg_Mg_pH10: 0.23668 - deg_Mg_50C: 0.19144
# Epoch 196/300   -   loss: 0.15009 - val_loss: 0.21309 - val_clean_loss: 0.20466 - val_aug_loss: 0.20443 - reactivity: 0.18946 - deg_Mg_pH10: 0.23451 - deg_Mg_50C: 0.18931
# Epoch 197/300   -   loss: 0.15038 - val_loss: 0.21669 - val_clean_loss: 0.20808 - val_aug_loss: 0.20777 - reactivity: 0.19365 - deg_Mg_pH10: 0.23648 - deg_Mg_50C: 0.19316
# Epoch 198/300   -   loss: 0.15019 - val_loss: 0.21314 - val_clean_loss: 0.20444 - val_aug_loss: 0.20418 - reactivity: 0.18909 - deg_Mg_pH10: 0.23474 - deg_Mg_50C: 0.18872
# Epoch 199/300   -   loss: 0.14953 - val_loss: 0.21691 - val_clean_loss: 0.20831 - val_aug_loss: 0.20802 - reactivity: 0.19349 - deg_Mg_pH10: 0.23797 - deg_Mg_50C: 0.19259
# Epoch 200/300   -   loss: 0.14801 - val_loss: 0.21446 - val_clean_loss: 0.20578 - val_aug_loss: 0.20555 - reactivity: 0.19024 - deg_Mg_pH10: 0.23522 - deg_Mg_50C: 0.19118
# Epoch 201/300   -   loss: 0.14784 - val_loss: 0.21523 - val_clean_loss: 0.20689 - val_aug_loss: 0.20667 - reactivity: 0.19139 - deg_Mg_pH10: 0.23615 - deg_Mg_50C: 0.19246
# Epoch 202/300   -   loss: 0.14793 - val_loss: 0.21361 - val_clean_loss: 0.20520 - val_aug_loss: 0.20500 - reactivity: 0.19029 - deg_Mg_pH10: 0.23467 - deg_Mg_50C: 0.19003
# Epoch 203/300   -   loss: 0.14761 - val_loss: 0.21555 - val_clean_loss: 0.20642 - val_aug_loss: 0.20615 - reactivity: 0.19072 - deg_Mg_pH10: 0.23638 - deg_Mg_50C: 0.19135
# Epoch 204/300   -   loss: 0.14709 - val_loss: 0.21404 - val_clean_loss: 0.20566 - val_aug_loss: 0.20537 - reactivity: 0.19017 - deg_Mg_pH10: 0.23508 - deg_Mg_50C: 0.19087
# Epoch 205/300   -   loss: 0.14717 - val_loss: 0.21496 - val_clean_loss: 0.20656 - val_aug_loss: 0.20633 - reactivity: 0.19081 - deg_Mg_pH10: 0.23648 - deg_Mg_50C: 0.19170
# Epoch 206/300   -   loss: 0.14754 - val_loss: 0.21563 - val_clean_loss: 0.20758 - val_aug_loss: 0.20720 - reactivity: 0.19140 - deg_Mg_pH10: 0.23709 - deg_Mg_50C: 0.19310
# Epoch 207/300   -   loss: 0.14726 - val_loss: 0.21396 - val_clean_loss: 0.20571 - val_aug_loss: 0.20544 - reactivity: 0.19123 - deg_Mg_pH10: 0.23549 - deg_Mg_50C: 0.18961
# Epoch 208/300   -   loss: 0.14681 - val_loss: 0.21513 - val_clean_loss: 0.20640 - val_aug_loss: 0.20610 - reactivity: 0.19099 - deg_Mg_pH10: 0.23615 - deg_Mg_50C: 0.19117
# Epoch 209/300   -   loss: 0.14684 - val_loss: 0.21533 - val_clean_loss: 0.20611 - val_aug_loss: 0.20586 - reactivity: 0.19027 - deg_Mg_pH10: 0.23648 - deg_Mg_50C: 0.19084
# Epoch 210/300   -   loss: 0.14573 - val_loss: 0.21415 - val_clean_loss: 0.20552 - val_aug_loss: 0.20527 - reactivity: 0.19065 - deg_Mg_pH10: 0.23540 - deg_Mg_50C: 0.18976
# Epoch 211/300   -   loss: 0.14596 - val_loss: 0.21648 - val_clean_loss: 0.20919 - val_aug_loss: 0.20894 - reactivity: 0.19531 - deg_Mg_pH10: 0.23849 - deg_Mg_50C: 0.19301
# Epoch 212/300   -   loss: 0.14621 - val_loss: 0.21376 - val_clean_loss: 0.20529 - val_aug_loss: 0.20505 - reactivity: 0.19024 - deg_Mg_pH10: 0.23523 - deg_Mg_50C: 0.18967
# Epoch 213/300   -   loss: 0.14566 - val_loss: 0.21413 - val_clean_loss: 0.20588 - val_aug_loss: 0.20562 - reactivity: 0.18949 - deg_Mg_pH10: 0.23638 - deg_Mg_50C: 0.19099
# Epoch 214/300   -   loss: 0.14561 - val_loss: 0.21404 - val_clean_loss: 0.20551 - val_aug_loss: 0.20521 - reactivity: 0.18905 - deg_Mg_pH10: 0.23576 - deg_Mg_50C: 0.19081
# Epoch 215/300   -   loss: 0.14506 - val_loss: 0.21720 - val_clean_loss: 0.20894 - val_aug_loss: 0.20860 - reactivity: 0.19322 - deg_Mg_pH10: 0.23862 - deg_Mg_50C: 0.19397
# Epoch 216/300   -   loss: 0.14568 - val_loss: 0.21400 - val_clean_loss: 0.20594 - val_aug_loss: 0.20561 - reactivity: 0.19042 - deg_Mg_pH10: 0.23613 - deg_Mg_50C: 0.19029
# Epoch 217/300   -   loss: 0.14456 - val_loss: 0.21358 - val_clean_loss: 0.20464 - val_aug_loss: 0.20442 - reactivity: 0.18989 - deg_Mg_pH10: 0.23481 - deg_Mg_50C: 0.18855
# Epoch 218/300   -   loss: 0.14524 - val_loss: 0.21487 - val_clean_loss: 0.20675 - val_aug_loss: 0.20646 - reactivity: 0.19155 - deg_Mg_pH10: 0.23638 - deg_Mg_50C: 0.19147
# Epoch 219/300   -   loss: 0.14461 - val_loss: 0.21420 - val_clean_loss: 0.20648 - val_aug_loss: 0.20620 - reactivity: 0.19070 - deg_Mg_pH10: 0.23530 - deg_Mg_50C: 0.19259
# Epoch 220/300   -   loss: 0.14442 - val_loss: 0.21295 - val_clean_loss: 0.20447 - val_aug_loss: 0.20424 - reactivity: 0.18971 - deg_Mg_pH10: 0.23371 - deg_Mg_50C: 0.18930
# Epoch 221/300   -   loss: 0.14416 - val_loss: 0.21349 - val_clean_loss: 0.20481 - val_aug_loss: 0.20456 - reactivity: 0.18996 - deg_Mg_pH10: 0.23394 - deg_Mg_50C: 0.18978
# Epoch 222/300   -   loss: 0.14413 - val_loss: 0.21427 - val_clean_loss: 0.20517 - val_aug_loss: 0.20491 - reactivity: 0.18932 - deg_Mg_pH10: 0.23471 - deg_Mg_50C: 0.19069
# Epoch 223/300   -   loss: 0.14443 - val_loss: 0.21494 - val_clean_loss: 0.20613 - val_aug_loss: 0.20593 - reactivity: 0.18993 - deg_Mg_pH10: 0.23678 - deg_Mg_50C: 0.19109
# Epoch 224/300   -   loss: 0.14442 - val_loss: 0.21371 - val_clean_loss: 0.20548 - val_aug_loss: 0.20527 - reactivity: 0.18971 - deg_Mg_pH10: 0.23517 - deg_Mg_50C: 0.19094
# Epoch 225/300   -   loss: 0.14385 - val_loss: 0.21514 - val_clean_loss: 0.20658 - val_aug_loss: 0.20642 - reactivity: 0.19062 - deg_Mg_pH10: 0.23694 - deg_Mg_50C: 0.19171
# Epoch 226/300   -   loss: 0.14330 - val_loss: 0.21381 - val_clean_loss: 0.20519 - val_aug_loss: 0.20500 - reactivity: 0.18939 - deg_Mg_pH10: 0.23531 - deg_Mg_50C: 0.19031
# Epoch 227/300   -   loss: 0.14299 - val_loss: 0.21408 - val_clean_loss: 0.20542 - val_aug_loss: 0.20528 - reactivity: 0.19010 - deg_Mg_pH10: 0.23576 - deg_Mg_50C: 0.18999
# Epoch 228/300   -   loss: 0.14348 - val_loss: 0.21356 - val_clean_loss: 0.20565 - val_aug_loss: 0.20540 - reactivity: 0.19020 - deg_Mg_pH10: 0.23507 - deg_Mg_50C: 0.19094
# Epoch 229/300   -   loss: 0.14288 - val_loss: 0.21375 - val_clean_loss: 0.20558 - val_aug_loss: 0.20535 - reactivity: 0.18950 - deg_Mg_pH10: 0.23556 - deg_Mg_50C: 0.19100
# Epoch 230/300   -   loss: 0.14274 - val_loss: 0.21252 - val_clean_loss: 0.20468 - val_aug_loss: 0.20450 - reactivity: 0.18905 - deg_Mg_pH10: 0.23455 - deg_Mg_50C: 0.18991
# Epoch 231/300   -   loss: 0.14239 - val_loss: 0.21532 - val_clean_loss: 0.20610 - val_aug_loss: 0.20592 - reactivity: 0.19021 - deg_Mg_pH10: 0.23606 - deg_Mg_50C: 0.19149
# Epoch 232/300   -   loss: 0.14303 - val_loss: 0.21425 - val_clean_loss: 0.20561 - val_aug_loss: 0.20539 - reactivity: 0.18996 - deg_Mg_pH10: 0.23538 - deg_Mg_50C: 0.19083
# Epoch 233/300   -   loss: 0.14324 - val_loss: 0.21310 - val_clean_loss: 0.20460 - val_aug_loss: 0.20440 - reactivity: 0.18855 - deg_Mg_pH10: 0.23611 - deg_Mg_50C: 0.18856
# Epoch 234/300   -   loss: 0.14254 - val_loss: 0.21540 - val_clean_loss: 0.20722 - val_aug_loss: 0.20695 - reactivity: 0.19068 - deg_Mg_pH10: 0.23766 - deg_Mg_50C: 0.19251
# Epoch 235/300   -   loss: 0.14243 - val_loss: 0.21386 - val_clean_loss: 0.20508 - val_aug_loss: 0.20490 - reactivity: 0.18850 - deg_Mg_pH10: 0.23645 - deg_Mg_50C: 0.18974
# Epoch 236/300   -   loss: 0.14305 - val_loss: 0.21286 - val_clean_loss: 0.20460 - val_aug_loss: 0.20438 - reactivity: 0.18847 - deg_Mg_pH10: 0.23466 - deg_Mg_50C: 0.19002
# Epoch 237/300   -   loss: 0.14198 - val_loss: 0.21491 - val_clean_loss: 0.20643 - val_aug_loss: 0.20620 - reactivity: 0.19157 - deg_Mg_pH10: 0.23645 - deg_Mg_50C: 0.19058
# Epoch 238/300   -   loss: 0.14085 - val_loss: 0.21312 - val_clean_loss: 0.20475 - val_aug_loss: 0.20454 - reactivity: 0.18878 - deg_Mg_pH10: 0.23535 - deg_Mg_50C: 0.18949
# Epoch 239/300   -   loss: 0.14084 - val_loss: 0.21386 - val_clean_loss: 0.20545 - val_aug_loss: 0.20528 - reactivity: 0.18896 - deg_Mg_pH10: 0.23675 - deg_Mg_50C: 0.19013
# Epoch 240/300   -   loss: 0.14093 - val_loss: 0.21349 - val_clean_loss: 0.20580 - val_aug_loss: 0.20560 - reactivity: 0.18993 - deg_Mg_pH10: 0.23605 - deg_Mg_50C: 0.19083
# Epoch 241/300   -   loss: 0.14104 - val_loss: 0.21450 - val_clean_loss: 0.20695 - val_aug_loss: 0.20673 - reactivity: 0.19220 - deg_Mg_pH10: 0.23611 - deg_Mg_50C: 0.19188
# Epoch 242/300   -   loss: 0.14095 - val_loss: 0.21295 - val_clean_loss: 0.20477 - val_aug_loss: 0.20456 - reactivity: 0.18864 - deg_Mg_pH10: 0.23530 - deg_Mg_50C: 0.18974
# Epoch 243/300   -   loss: 0.14106 - val_loss: 0.21294 - val_clean_loss: 0.20473 - val_aug_loss: 0.20452 - reactivity: 0.18874 - deg_Mg_pH10: 0.23560 - deg_Mg_50C: 0.18921
# Epoch 244/300   -   loss: 0.14048 - val_loss: 0.21395 - val_clean_loss: 0.20646 - val_aug_loss: 0.20620 - reactivity: 0.19106 - deg_Mg_pH10: 0.23588 - deg_Mg_50C: 0.19168
# Epoch 245/300   -   loss: 0.13969 - val_loss: 0.21253 - val_clean_loss: 0.20498 - val_aug_loss: 0.20484 - reactivity: 0.18924 - deg_Mg_pH10: 0.23542 - deg_Mg_50C: 0.18987
# Epoch 246/300   -   loss: 0.14003 - val_loss: 0.21272 - val_clean_loss: 0.20504 - val_aug_loss: 0.20484 - reactivity: 0.18999 - deg_Mg_pH10: 0.23447 - deg_Mg_50C: 0.19006
# Epoch 247/300   -   loss: 0.13921 - val_loss: 0.21437 - val_clean_loss: 0.20634 - val_aug_loss: 0.20617 - reactivity: 0.19067 - deg_Mg_pH10: 0.23668 - deg_Mg_50C: 0.19117
# Epoch 248/300   -   loss: 0.14097 - val_loss: 0.21326 - val_clean_loss: 0.20495 - val_aug_loss: 0.20473 - reactivity: 0.18954 - deg_Mg_pH10: 0.23516 - deg_Mg_50C: 0.18948
# Epoch 249/300   -   loss: 0.13950 - val_loss: 0.21437 - val_clean_loss: 0.20611 - val_aug_loss: 0.20587 - reactivity: 0.19091 - deg_Mg_pH10: 0.23614 - deg_Mg_50C: 0.19055
# Epoch 250/300   -   loss: 0.13987 - val_loss: 0.21252 - val_clean_loss: 0.20417 - val_aug_loss: 0.20403 - reactivity: 0.18925 - deg_Mg_pH10: 0.23381 - deg_Mg_50C: 0.18905
# Epoch 251/300   -   loss: 0.13990 - val_loss: 0.21435 - val_clean_loss: 0.20617 - val_aug_loss: 0.20597 - reactivity: 0.19086 - deg_Mg_pH10: 0.23556 - deg_Mg_50C: 0.19150
# Epoch 252/300   -   loss: 0.13913 - val_loss: 0.21336 - val_clean_loss: 0.20505 - val_aug_loss: 0.20486 - reactivity: 0.18973 - deg_Mg_pH10: 0.23502 - deg_Mg_50C: 0.18981
# Epoch 253/300   -   loss: 0.13879 - val_loss: 0.21308 - val_clean_loss: 0.20480 - val_aug_loss: 0.20461 - reactivity: 0.18914 - deg_Mg_pH10: 0.23533 - deg_Mg_50C: 0.18936
# Epoch 254/300   -   loss: 0.13927 - val_loss: 0.21401 - val_clean_loss: 0.20572 - val_aug_loss: 0.20552 - reactivity: 0.19016 - deg_Mg_pH10: 0.23553 - deg_Mg_50C: 0.19088
# Epoch 255/300   -   loss: 0.13896 - val_loss: 0.21415 - val_clean_loss: 0.20594 - val_aug_loss: 0.20576 - reactivity: 0.18982 - deg_Mg_pH10: 0.23536 - deg_Mg_50C: 0.19209
# Epoch 256/300   -   loss: 0.13801 - val_loss: 0.21400 - val_clean_loss: 0.20593 - val_aug_loss: 0.20571 - reactivity: 0.19031 - deg_Mg_pH10: 0.23556 - deg_Mg_50C: 0.19126
# Epoch 257/300   -   loss: 0.13806 - val_loss: 0.21491 - val_clean_loss: 0.20589 - val_aug_loss: 0.20567 - reactivity: 0.18985 - deg_Mg_pH10: 0.23675 - deg_Mg_50C: 0.19042
# Epoch 258/300   -   loss: 0.13786 - val_loss: 0.21362 - val_clean_loss: 0.20567 - val_aug_loss: 0.20544 - reactivity: 0.19030 - deg_Mg_pH10: 0.23562 - deg_Mg_50C: 0.19041
# Epoch 259/300   -   loss: 0.13813 - val_loss: 0.21500 - val_clean_loss: 0.20741 - val_aug_loss: 0.20712 - reactivity: 0.19224 - deg_Mg_pH10: 0.23647 - deg_Mg_50C: 0.19265
# Epoch 260/300   -   loss: 0.13842 - val_loss: 0.21203 - val_clean_loss: 0.20425 - val_aug_loss: 0.20400 - reactivity: 0.18895 - deg_Mg_pH10: 0.23403 - deg_Mg_50C: 0.18902
# Epoch 261/300   -   loss: 0.13733 - val_loss: 0.21647 - val_clean_loss: 0.20831 - val_aug_loss: 0.20801 - reactivity: 0.19252 - deg_Mg_pH10: 0.23820 - deg_Mg_50C: 0.19331
# Epoch 262/300   -   loss: 0.13774 - val_loss: 0.21227 - val_clean_loss: 0.20410 - val_aug_loss: 0.20392 - reactivity: 0.18820 - deg_Mg_pH10: 0.23434 - deg_Mg_50C: 0.18923
# Epoch 263/300   -   loss: 0.13795 - val_loss: 0.21428 - val_clean_loss: 0.20710 - val_aug_loss: 0.20689 - reactivity: 0.19085 - deg_Mg_pH10: 0.23704 - deg_Mg_50C: 0.19279
# Epoch 264/300   -   loss: 0.13793 - val_loss: 0.21319 - val_clean_loss: 0.20534 - val_aug_loss: 0.20509 - reactivity: 0.18944 - deg_Mg_pH10: 0.23590 - deg_Mg_50C: 0.18992
# Epoch 265/300   -   loss: 0.13769 - val_loss: 0.21408 - val_clean_loss: 0.20567 - val_aug_loss: 0.20542 - reactivity: 0.18918 - deg_Mg_pH10: 0.23599 - deg_Mg_50C: 0.19109
# Epoch 266/300   -   loss: 0.13708 - val_loss: 0.21449 - val_clean_loss: 0.20640 - val_aug_loss: 0.20612 - reactivity: 0.19065 - deg_Mg_pH10: 0.23606 - deg_Mg_50C: 0.19164
# Epoch 267/300   -   loss: 0.13691 - val_loss: 0.21472 - val_clean_loss: 0.20599 - val_aug_loss: 0.20573 - reactivity: 0.19210 - deg_Mg_pH10: 0.23502 - deg_Mg_50C: 0.19007
# Epoch 268/300   -   loss: 0.13694 - val_loss: 0.21351 - val_clean_loss: 0.20524 - val_aug_loss: 0.20503 - reactivity: 0.19043 - deg_Mg_pH10: 0.23502 - deg_Mg_50C: 0.18965
# Epoch 269/300   -   loss: 0.13655 - val_loss: 0.21396 - val_clean_loss: 0.20564 - val_aug_loss: 0.20546 - reactivity: 0.18997 - deg_Mg_pH10: 0.23652 - deg_Mg_50C: 0.18990
# Epoch 270/300   -   loss: 0.13611 - val_loss: 0.21462 - val_clean_loss: 0.20627 - val_aug_loss: 0.20603 - reactivity: 0.19082 - deg_Mg_pH10: 0.23591 - deg_Mg_50C: 0.19136
# Epoch 271/300   -   loss: 0.13615 - val_loss: 0.21464 - val_clean_loss: 0.20649 - val_aug_loss: 0.20628 - reactivity: 0.19118 - deg_Mg_pH10: 0.23700 - deg_Mg_50C: 0.19065
# Epoch 272/300   -   loss: 0.13662 - val_loss: 0.21294 - val_clean_loss: 0.20437 - val_aug_loss: 0.20421 - reactivity: 0.18960 - deg_Mg_pH10: 0.23417 - deg_Mg_50C: 0.18885
# Epoch 273/300   -   loss: 0.13577 - val_loss: 0.21511 - val_clean_loss: 0.20697 - val_aug_loss: 0.20682 - reactivity: 0.19237 - deg_Mg_pH10: 0.23707 - deg_Mg_50C: 0.19102
# Epoch 274/300   -   loss: 0.13645 - val_loss: 0.21379 - val_clean_loss: 0.20536 - val_aug_loss: 0.20519 - reactivity: 0.19053 - deg_Mg_pH10: 0.23502 - deg_Mg_50C: 0.19002
# Epoch 275/300   -   loss: 0.13667 - val_loss: 0.21382 - val_clean_loss: 0.20544 - val_aug_loss: 0.20525 - reactivity: 0.19027 - deg_Mg_pH10: 0.23614 - deg_Mg_50C: 0.18935
# Epoch 276/300   -   loss: 0.13595 - val_loss: 0.21368 - val_clean_loss: 0.20551 - val_aug_loss: 0.20524 - reactivity: 0.18913 - deg_Mg_pH10: 0.23572 - deg_Mg_50C: 0.19089
# Epoch 277/300   -   loss: 0.13557 - val_loss: 0.21327 - val_clean_loss: 0.20502 - val_aug_loss: 0.20480 - reactivity: 0.18965 - deg_Mg_pH10: 0.23454 - deg_Mg_50C: 0.19022
# Epoch 278/300   -   loss: 0.13526 - val_loss: 0.21309 - val_clean_loss: 0.20495 - val_aug_loss: 0.20472 - reactivity: 0.19032 - deg_Mg_pH10: 0.23448 - deg_Mg_50C: 0.18935
# ...
# Epoch 208/300   -   loss: 0.14674 - val_loss: 0.20891 - val_clean_loss: 0.20672 - val_aug_loss: 0.20661 - reactivity: 0.19335 - deg_Mg_pH10: 0.22727 - deg_Mg_50C: 0.19920
# Epoch 209/300   -   loss: 0.14508 - val_loss: 0.20947 - val_clean_loss: 0.20734 - val_aug_loss: 0.20726 - reactivity: 0.19476 - deg_Mg_pH10: 0.22825 - deg_Mg_50C: 0.19879
# Epoch 210/300   -   loss: 0.14569 - val_loss: 0.20846 - val_clean_loss: 0.20656 - val_aug_loss: 0.20648 - reactivity: 0.19364 - deg_Mg_pH10: 0.22730 - deg_Mg_50C: 0.19852
# Epoch 211/300   -   loss: 0.14523 - val_loss: 0.20920 - val_clean_loss: 0.20725 - val_aug_loss: 0.20718 - reactivity: 0.19355 - deg_Mg_pH10: 0.22855 - deg_Mg_50C: 0.19943
# Epoch 212/300   -   loss: 0.14527 - val_loss: 0.20861 - val_clean_loss: 0.20687 - val_aug_loss: 0.20682 - reactivity: 0.19349 - deg_Mg_pH10: 0.22821 - deg_Mg_50C: 0.19876
# Epoch 213/300   -   loss: 0.14418 - val_loss: 0.21126 - val_clean_loss: 0.21010 - val_aug_loss: 0.21003 - reactivity: 0.19493 - deg_Mg_pH10: 0.23169 - deg_Mg_50C: 0.20346
# Epoch 214/300   -   loss: 0.14516 - val_loss: 0.20914 - val_clean_loss: 0.20789 - val_aug_loss: 0.20781 - reactivity: 0.19397 - deg_Mg_pH10: 0.23001 - deg_Mg_50C: 0.19946
# Epoch 215/300   -   loss: 0.14513 - val_loss: 0.21012 - val_clean_loss: 0.20815 - val_aug_loss: 0.20806 - reactivity: 0.19468 - deg_Mg_pH10: 0.23050 - deg_Mg_50C: 0.19901
# Epoch 216/300   -   loss: 0.14500 - val_loss: 0.20861 - val_clean_loss: 0.20725 - val_aug_loss: 0.20714 - reactivity: 0.19335 - deg_Mg_pH10: 0.22984 - deg_Mg_50C: 0.19823
# Epoch 217/300   -   loss: 0.14352 - val_loss: 0.20939 - val_clean_loss: 0.20791 - val_aug_loss: 0.20771 - reactivity: 0.19435 - deg_Mg_pH10: 0.22981 - deg_Mg_50C: 0.19897
# Epoch 218/300   -   loss: 0.14471 - val_loss: 0.20880 - val_clean_loss: 0.20691 - val_aug_loss: 0.20674 - reactivity: 0.19387 - deg_Mg_pH10: 0.22729 - deg_Mg_50C: 0.19907
# Epoch 219/300   -   loss: 0.14389 - val_loss: 0.21103 - val_clean_loss: 0.20962 - val_aug_loss: 0.20945 - reactivity: 0.19677 - deg_Mg_pH10: 0.23051 - deg_Mg_50C: 0.20107
# Epoch 220/300   -   loss: 0.14432 - val_loss: 0.20835 - val_clean_loss: 0.20645 - val_aug_loss: 0.20630 - reactivity: 0.19385 - deg_Mg_pH10: 0.22765 - deg_Mg_50C: 0.19742
# Epoch 221/300   -   loss: 0.14431 - val_loss: 0.20956 - val_clean_loss: 0.20692 - val_aug_loss: 0.20687 - reactivity: 0.19349 - deg_Mg_pH10: 0.22817 - deg_Mg_50C: 0.19895
# Epoch 222/300   -   loss: 0.14453 - val_loss: 0.20853 - val_clean_loss: 0.20691 - val_aug_loss: 0.20683 - reactivity: 0.19411 - deg_Mg_pH10: 0.22776 - deg_Mg_50C: 0.19862
# Epoch 223/300   -   loss: 0.14358 - val_loss: 0.21197 - val_clean_loss: 0.21153 - val_aug_loss: 0.21142 - reactivity: 0.19806 - deg_Mg_pH10: 0.23375 - deg_Mg_50C: 0.20245
# Epoch 224/300   -   loss: 0.14387 - val_loss: 0.20860 - val_clean_loss: 0.20711 - val_aug_loss: 0.20702 - reactivity: 0.19456 - deg_Mg_pH10: 0.22704 - deg_Mg_50C: 0.19947
# Epoch 225/300   -   loss: 0.14270 - val_loss: 0.20974 - val_clean_loss: 0.20896 - val_aug_loss: 0.20889 - reactivity: 0.19586 - deg_Mg_pH10: 0.23159 - deg_Mg_50C: 0.19923
# Epoch 226/300   -   loss: 0.14261 - val_loss: 0.20914 - val_clean_loss: 0.20763 - val_aug_loss: 0.20754 - reactivity: 0.19433 - deg_Mg_pH10: 0.22835 - deg_Mg_50C: 0.19994
# Epoch 227/300   -   loss: 0.14309 - val_loss: 0.21133 - val_clean_loss: 0.20976 - val_aug_loss: 0.20961 - reactivity: 0.19616 - deg_Mg_pH10: 0.23076 - deg_Mg_50C: 0.20192
# Epoch 228/300   -   loss: 0.14315 - val_loss: 0.20861 - val_clean_loss: 0.20738 - val_aug_loss: 0.20728 - reactivity: 0.19478 - deg_Mg_pH10: 0.22862 - deg_Mg_50C: 0.19844
# Epoch 229/300   -   loss: 0.14296 - val_loss: 0.21289 - val_clean_loss: 0.21153 - val_aug_loss: 0.21138 - reactivity: 0.19820 - deg_Mg_pH10: 0.23339 - deg_Mg_50C: 0.20256
# Epoch 230/300   -   loss: 0.14322 - val_loss: 0.20890 - val_clean_loss: 0.20717 - val_aug_loss: 0.20709 - reactivity: 0.19398 - deg_Mg_pH10: 0.22891 - deg_Mg_50C: 0.19839
# Epoch 231/300   -   loss: 0.14248 - val_loss: 0.20940 - val_clean_loss: 0.20735 - val_aug_loss: 0.20723 - reactivity: 0.19365 - deg_Mg_pH10: 0.22898 - deg_Mg_50C: 0.19906
# Epoch 232/300   -   loss: 0.14239 - val_loss: 0.20800 - val_clean_loss: 0.20734 - val_aug_loss: 0.20717 - reactivity: 0.19416 - deg_Mg_pH10: 0.22968 - deg_Mg_50C: 0.19767
# Epoch 233/300   -   loss: 0.14201 - val_loss: 0.20943 - val_clean_loss: 0.20788 - val_aug_loss: 0.20771 - reactivity: 0.19440 - deg_Mg_pH10: 0.23004 - deg_Mg_50C: 0.19868
# Epoch 234/300   -   loss: 0.14190 - val_loss: 0.20890 - val_clean_loss: 0.20731 - val_aug_loss: 0.20719 - reactivity: 0.19380 - deg_Mg_pH10: 0.22845 - deg_Mg_50C: 0.19932
# Epoch 235/300   -   loss: 0.14054 - val_loss: 0.20920 - val_clean_loss: 0.20751 - val_aug_loss: 0.20741 - reactivity: 0.19375 - deg_Mg_pH10: 0.22930 - deg_Mg_50C: 0.19918
# Epoch 236/300   -   loss: 0.14148 - val_loss: 0.20924 - val_clean_loss: 0.20750 - val_aug_loss: 0.20736 - reactivity: 0.19453 - deg_Mg_pH10: 0.22818 - deg_Mg_50C: 0.19937
# Epoch 237/300   -   loss: 0.14027 - val_loss: 0.21057 - val_clean_loss: 0.20927 - val_aug_loss: 0.20913 - reactivity: 0.19610 - deg_Mg_pH10: 0.23164 - deg_Mg_50C: 0.19966
# Epoch 238/300   -   loss: 0.14063 - val_loss: 0.20869 - val_clean_loss: 0.20732 - val_aug_loss: 0.20714 - reactivity: 0.19436 - deg_Mg_pH10: 0.22834 - deg_Mg_50C: 0.19872
# Epoch 239/300   -   loss: 0.14056 - val_loss: 0.20893 - val_clean_loss: 0.20698 - val_aug_loss: 0.20683 - reactivity: 0.19465 - deg_Mg_pH10: 0.22687 - deg_Mg_50C: 0.19898
# Epoch 240/300   -   loss: 0.14048 - val_loss: 0.20854 - val_clean_loss: 0.20690 - val_aug_loss: 0.20673 - reactivity: 0.19421 - deg_Mg_pH10: 0.22748 - deg_Mg_50C: 0.19850
# Epoch 241/300   -   loss: 0.13994 - val_loss: 0.20893 - val_clean_loss: 0.20699 - val_aug_loss: 0.20681 - reactivity: 0.19348 - deg_Mg_pH10: 0.22841 - deg_Mg_50C: 0.19855
# Epoch 242/300   -   loss: 0.14088 - val_loss: 0.20959 - val_clean_loss: 0.20835 - val_aug_loss: 0.20823 - reactivity: 0.19561 - deg_Mg_pH10: 0.22900 - deg_Mg_50C: 0.20006
# Epoch 243/300   -   loss: 0.14029 - val_loss: 0.20895 - val_clean_loss: 0.20728 - val_aug_loss: 0.20712 - reactivity: 0.19511 - deg_Mg_pH10: 0.22869 - deg_Mg_50C: 0.19758
# Epoch 244/300   -   loss: 0.13999 - val_loss: 0.21150 - val_clean_loss: 0.21014 - val_aug_loss: 0.21001 - reactivity: 0.19658 - deg_Mg_pH10: 0.23121 - deg_Mg_50C: 0.20225
# Epoch 245/300   -   loss: 0.13983 - val_loss: 0.21022 - val_clean_loss: 0.20838 - val_aug_loss: 0.20823 - reactivity: 0.19504 - deg_Mg_pH10: 0.22927 - deg_Mg_50C: 0.20040
# Epoch 246/300   -   loss: 0.14094 - val_loss: 0.20970 - val_clean_loss: 0.20874 - val_aug_loss: 0.20864 - reactivity: 0.19581 - deg_Mg_pH10: 0.23074 - deg_Mg_50C: 0.19937
# Epoch 247/300   -   loss: 0.13974 - val_loss: 0.20984 - val_clean_loss: 0.20806 - val_aug_loss: 0.20795 - reactivity: 0.19454 - deg_Mg_pH10: 0.22995 - deg_Mg_50C: 0.19936
# Epoch 248/300   -   loss: 0.13995 - val_loss: 0.20932 - val_clean_loss: 0.20820 - val_aug_loss: 0.20813 - reactivity: 0.19532 - deg_Mg_pH10: 0.23012 - deg_Mg_50C: 0.19894
# Epoch 249/300   -   loss: 0.13942 - val_loss: 0.21318 - val_clean_loss: 0.21138 - val_aug_loss: 0.21128 - reactivity: 0.20004 - deg_Mg_pH10: 0.23246 - deg_Mg_50C: 0.20134
# Epoch 250/300   -   loss: 0.13961 - val_loss: 0.20991 - val_clean_loss: 0.20823 - val_aug_loss: 0.20816 - reactivity: 0.19623 - deg_Mg_pH10: 0.22835 - deg_Mg_50C: 0.19990
# Epoch 251/300   -   loss: 0.13875 - val_loss: 0.20981 - val_clean_loss: 0.20909 - val_aug_loss: 0.20902 - reactivity: 0.19718 - deg_Mg_pH10: 0.23074 - deg_Mg_50C: 0.19915
# Epoch 252/300   -   loss: 0.14046 - val_loss: 0.20918 - val_clean_loss: 0.20775 - val_aug_loss: 0.20765 - reactivity: 0.19540 - deg_Mg_pH10: 0.22834 - deg_Mg_50C: 0.19922
# Epoch 253/300   -   loss: 0.13905 - val_loss: 0.21245 - val_clean_loss: 0.21008 - val_aug_loss: 0.20995 - reactivity: 0.19742 - deg_Mg_pH10: 0.23025 - deg_Mg_50C: 0.20219
# Epoch 254/300   -   loss: 0.13878 - val_loss: 0.20941 - val_clean_loss: 0.20810 - val_aug_loss: 0.20796 - reactivity: 0.19569 - deg_Mg_pH10: 0.22908 - deg_Mg_50C: 0.19910
# Epoch 255/300   -   loss: 0.13842 - val_loss: 0.21009 - val_clean_loss: 0.20838 - val_aug_loss: 0.20825 - reactivity: 0.19442 - deg_Mg_pH10: 0.22963 - deg_Mg_50C: 0.20071
# Epoch 256/300   -   loss: 0.13813 - val_loss: 0.20862 - val_clean_loss: 0.20664 - val_aug_loss: 0.20654 - reactivity: 0.19385 - deg_Mg_pH10: 0.22694 - deg_Mg_50C: 0.19884
# Epoch 257/300   -   loss: 0.13746 - val_loss: 0.21119 - val_clean_loss: 0.20979 - val_aug_loss: 0.20965 - reactivity: 0.19786 - deg_Mg_pH10: 0.23124 - deg_Mg_50C: 0.19986
# Epoch 258/300   -   loss: 0.13802 - val_loss: 0.20860 - val_clean_loss: 0.20713 - val_aug_loss: 0.20704 - reactivity: 0.19394 - deg_Mg_pH10: 0.22901 - deg_Mg_50C: 0.19816
# Epoch 259/300   -   loss: 0.13746 - val_loss: 0.21049 - val_clean_loss: 0.20825 - val_aug_loss: 0.20820 - reactivity: 0.19457 - deg_Mg_pH10: 0.22864 - deg_Mg_50C: 0.20139
# Epoch 260/300   -   loss: 0.13799 - val_loss: 0.20846 - val_clean_loss: 0.20671 - val_aug_loss: 0.20660 - reactivity: 0.19350 - deg_Mg_pH10: 0.22751 - deg_Mg_50C: 0.19879
# Epoch 261/300   -   loss: 0.13695 - val_loss: 0.20783 - val_clean_loss: 0.20526 - val_aug_loss: 0.20514 - reactivity: 0.19187 - deg_Mg_pH10: 0.22592 - deg_Mg_50C: 0.19764
# Epoch 262/300   -   loss: 0.13684 - val_loss: 0.20845 - val_clean_loss: 0.20733 - val_aug_loss: 0.20718 - reactivity: 0.19392 - deg_Mg_pH10: 0.22888 - deg_Mg_50C: 0.19873
# Epoch 263/300   -   loss: 0.13667 - val_loss: 0.21152 - val_clean_loss: 0.20995 - val_aug_loss: 0.20979 - reactivity: 0.19605 - deg_Mg_pH10: 0.23076 - deg_Mg_50C: 0.20256
# Epoch 264/300   -   loss: 0.13744 - val_loss: 0.20809 - val_clean_loss: 0.20654 - val_aug_loss: 0.20646 - reactivity: 0.19332 - deg_Mg_pH10: 0.22791 - deg_Mg_50C: 0.19815
# Epoch 265/300   -   loss: 0.13697 - val_loss: 0.21000 - val_clean_loss: 0.20790 - val_aug_loss: 0.20777 - reactivity: 0.19391 - deg_Mg_pH10: 0.22887 - deg_Mg_50C: 0.20052
# Epoch 266/300   -   loss: 0.13895 - val_loss: 0.20986 - val_clean_loss: 0.20827 - val_aug_loss: 0.20819 - reactivity: 0.19541 - deg_Mg_pH10: 0.22937 - deg_Mg_50C: 0.19979
# Epoch 267/300   -   loss: 0.13765 - val_loss: 0.20973 - val_clean_loss: 0.20840 - val_aug_loss: 0.20834 - reactivity: 0.19478 - deg_Mg_pH10: 0.23031 - deg_Mg_50C: 0.19992
# Epoch 268/300   -   loss: 0.13780 - val_loss: 0.20929 - val_clean_loss: 0.20687 - val_aug_loss: 0.20678 - reactivity: 0.19433 - deg_Mg_pH10: 0.22767 - deg_Mg_50C: 0.19833
# Epoch 269/300   -   loss: 0.13722 - val_loss: 0.20962 - val_clean_loss: 0.20772 - val_aug_loss: 0.20765 - reactivity: 0.19705 - deg_Mg_pH10: 0.22756 - deg_Mg_50C: 0.19833
# Epoch 270/300   -   loss: 0.13690 - val_loss: 0.20852 - val_clean_loss: 0.20652 - val_aug_loss: 0.20648 - reactivity: 0.19440 - deg_Mg_pH10: 0.22677 - deg_Mg_50C: 0.19826
# Epoch 271/300   -   loss: 0.13603 - val_loss: 0.20874 - val_clean_loss: 0.20670 - val_aug_loss: 0.20663 - reactivity: 0.19417 - deg_Mg_pH10: 0.22750 - deg_Mg_50C: 0.19822
# Epoch 272/300   -   loss: 0.13566 - val_loss: 0.20902 - val_clean_loss: 0.20731 - val_aug_loss: 0.20714 - reactivity: 0.19449 - deg_Mg_pH10: 0.22729 - deg_Mg_50C: 0.19964
# Epoch 273/300   -   loss: 0.13514 - val_loss: 0.21033 - val_clean_loss: 0.20819 - val_aug_loss: 0.20799 - reactivity: 0.19566 - deg_Mg_pH10: 0.22932 - deg_Mg_50C: 0.19899
# Epoch 274/300   -   loss: 0.13627 - val_loss: 0.20890 - val_clean_loss: 0.20687 - val_aug_loss: 0.20669 - reactivity: 0.19387 - deg_Mg_pH10: 0.22755 - deg_Mg_50C: 0.19866
# Epoch 275/300   -   loss: 0.13573 - val_loss: 0.21155 - val_clean_loss: 0.21038 - val_aug_loss: 0.21018 - reactivity: 0.19884 - deg_Mg_pH10: 0.22995 - deg_Mg_50C: 0.20175
# Epoch 276/300   -   loss: 0.13597 - val_loss: 0.20934 - val_clean_loss: 0.20789 - val_aug_loss: 0.20768 - reactivity: 0.19537 - deg_Mg_pH10: 0.22820 - deg_Mg_50C: 0.19946
# Epoch 277/300   -   loss: 0.13530 - val_loss: 0.21243 - val_clean_loss: 0.21119 - val_aug_loss: 0.21099 - reactivity: 0.19599 - deg_Mg_pH10: 0.23277 - deg_Mg_50C: 0.20420
# Epoch 278/300   -   loss: 0.13512 - val_loss: 0.20881 - val_clean_loss: 0.20728 - val_aug_loss: 0.20705 - reactivity: 0.19360 - deg_Mg_pH10: 0.22837 - deg_Mg_50C: 0.19918
# Epoch 279/300   -   loss: 0.13502 - val_loss: 0.20994 - val_clean_loss: 0.20802 - val_aug_loss: 0.20786 - reactivity: 0.19488 - deg_Mg_pH10: 0.22911 - deg_Mg_50C: 0.19958
# Epoch 280/300   -   loss: 0.13491 - val_loss: 0.20941 - val_clean_loss: 0.20754 - val_aug_loss: 0.20740 - reactivity: 0.19388 - deg_Mg_pH10: 0.22874 - deg_Mg_50C: 0.19960
# Epoch 281/300   -   loss: 0.13444 - val_loss: 0.20870 - val_clean_loss: 0.20750 - val_aug_loss: 0.20740 - reactivity: 0.19511 - deg_Mg_pH10: 0.22850 - deg_Mg_50C: 0.19858
# Epoch 282/300   -   loss: 0.13504 - val_loss: 0.20755 - val_clean_loss: 0.20577 - val_aug_loss: 0.20568 - reactivity: 0.19289 - deg_Mg_pH10: 0.22680 - deg_Mg_50C: 0.19734
# Epoch 283/300   -   loss: 0.13540 - val_loss: 0.21174 - val_clean_loss: 0.21080 - val_aug_loss: 0.21049 - reactivity: 0.19585 - deg_Mg_pH10: 0.23230 - deg_Mg_50C: 0.20332
# Epoch 284/300   -   loss: 0.13515 - val_loss: 0.20866 - val_clean_loss: 0.20729 - val_aug_loss: 0.20700 - reactivity: 0.19402 - deg_Mg_pH10: 0.22822 - deg_Mg_50C: 0.19877
# Epoch 285/300   -   loss: 0.13418 - val_loss: 0.20937 - val_clean_loss: 0.20709 - val_aug_loss: 0.20689 - reactivity: 0.19334 - deg_Mg_pH10: 0.22701 - deg_Mg_50C: 0.20032
# Epoch 286/300   -   loss: 0.13393 - val_loss: 0.20926 - val_clean_loss: 0.20751 - val_aug_loss: 0.20731 - reactivity: 0.19381 - deg_Mg_pH10: 0.22853 - deg_Mg_50C: 0.19961
# Epoch 287/300   -   loss: 0.13384 - val_loss: 0.21118 - val_clean_loss: 0.21071 - val_aug_loss: 0.21049 - reactivity: 0.19640 - deg_Mg_pH10: 0.23266 - deg_Mg_50C: 0.20241
# Epoch 288/300   -   loss: 0.13393 - val_loss: 0.20860 - val_clean_loss: 0.20736 - val_aug_loss: 0.20717 - reactivity: 0.19314 - deg_Mg_pH10: 0.22943 - deg_Mg_50C: 0.19896
# Epoch 289/300   -   loss: 0.13351 - val_loss: 0.20934 - val_clean_loss: 0.20780 - val_aug_loss: 0.20763 - reactivity: 0.19349 - deg_Mg_pH10: 0.22940 - deg_Mg_50C: 0.20001
# Epoch 290/300   -   loss: 0.13364 - val_loss: 0.20913 - val_clean_loss: 0.20786 - val_aug_loss: 0.20769 - reactivity: 0.19503 - deg_Mg_pH10: 0.22933 - deg_Mg_50C: 0.19871
# Epoch 291/300   -   loss: 0.13366 - val_loss: 0.21089 - val_clean_loss: 0.20918 - val_aug_loss: 0.20905 - reactivity: 0.19700 - deg_Mg_pH10: 0.22988 - deg_Mg_50C: 0.20028
# Epoch 292/300   -   loss: 0.13326 - val_loss: 0.20862 - val_clean_loss: 0.20711 - val_aug_loss: 0.20702 - reactivity: 0.19420 - deg_Mg_pH10: 0.22837 - deg_Mg_50C: 0.19850
# Epoch 293/300   -   loss: 0.13276 - val_loss: 0.21021 - val_clean_loss: 0.20848 - val_aug_loss: 0.20845 - reactivity: 0.19538 - deg_Mg_pH10: 0.23034 - deg_Mg_50C: 0.19963
# Epoch 294/300   -   loss: 0.13314 - val_loss: 0.20815 - val_clean_loss: 0.20661 - val_aug_loss: 0.20661 - reactivity: 0.19330 - deg_Mg_pH10: 0.22776 - deg_Mg_50C: 0.19877
# Epoch 295/300   -   loss: 0.13256 - val_loss: 0.20955 - val_clean_loss: 0.20791 - val_aug_loss: 0.20789 - reactivity: 0.19451 - deg_Mg_pH10: 0.22865 - deg_Mg_50C: 0.20051
# Epoch 296/300   -   loss: 0.13251 - val_loss: 0.20686 - val_clean_loss: 0.20482 - val_aug_loss: 0.20477 - reactivity: 0.19190 - deg_Mg_pH10: 0.22598 - deg_Mg_50C: 0.19642
# Epoch 297/300   -   loss: 0.13253 - val_loss: 0.21151 - val_clean_loss: 0.20984 - val_aug_loss: 0.20982 - reactivity: 0.19522 - deg_Mg_pH10: 0.23057 - deg_Mg_50C: 0.20366
# Epoch 298/300   -   loss: 0.13268 - val_loss: 0.20883 - val_clean_loss: 0.20740 - val_aug_loss: 0.20733 - reactivity: 0.19378 - deg_Mg_pH10: 0.22850 - deg_Mg_50C: 0.19971
# Epoch 299/300   -   loss: 0.13266 - val_loss: 0.20933 - val_clean_loss: 0.20814 - val_aug_loss: 0.20805 - reactivity: 0.19464 - deg_Mg_pH10: 0.22898 - deg_Mg_50C: 0.20054
# Epoch 300/300   -   loss: 0.13210 - val_loss: 0.20714 - val_clean_loss: 0.20564 - val_aug_loss: 0.20551 - reactivity: 0.19251 - deg_Mg_pH10: 0.22611 - deg_Mg_50C: 0.19792

# %%
for i in range(n_fold):
    print(f"fold {i+1} score:",cv_score[i])
print()
print("CV score:",np.mean(cv_score))
np.save('oof_{:5.5f}'.format(np.mean(cv_score)),oof)
# Out:
# fold 1 score: 0.20348056654135385
# fold 2 score: 0.2161213755607605
# fold 3 score: 0.2033812403678894
# fold 4 score: 0.21425066888332367
# fold 5 score: 0.2046167403459549
#
# CV score: 0.20837011833985644

# %%
dataset = Covid19Dataset(test_x,test_bpps,test_mat,test_length,test_scored)
args_loader = {'batch_size': 1, 'shuffle': False, 'num_workers': 0, 'pin_memory': True, 'drop_last': False}
test_loader = DataLoader(dataset, **args_loader)
test_predictions = np.zeros([len(test_x),130,5])
for j,col in enumerate(['reactivity', 'deg_Mg_pH10', 'deg_Mg_50C']):
    paths = glob(f'fold*_{col}_model.pt')
    with torch.no_grad():
        for path in tqdm(paths):
            model.load_state_dict(torch.load(path))
            model.eval().to(device)
            predictions = []
            for x_b,bpps_b,mask_b,scored_mask_b in test_loader:
                x_b = x_b.long().to(device)
                bpps_b = bpps_b.to(device)
                mask_b = mask_b.to(device)
                x_b_aug = x_b.clone()
                x_b_aug[:,:,-4] = x_b_aug[:,:,-2]
                x_b_aug[:,:,-3] = x_b_aug[:,:,-1]
                x_b_aug  = x_b_aug[:,:,:-2]
                bpps_b_aug = bpps_b.clone()
                bpps_b_aug[:,-2] = bpps_b_aug[:,-1]
                bpps_b_aug = bpps_b_aug[:,:-1]
                x_b = x_b[:,:,:-2]
                bpps_b = bpps_b[:,:-1]

                preds = model(x_b,bpps_b)
                preds_aug = model(x_b_aug,bpps_b_aug)
                preds = 0.5*(preds + preds_aug)

                p = torch.zeros([preds.shape[0],130,preds.shape[2]])
                p[:,:preds.shape[1]] = preds.cpu()
                predictions.append(p)
            predictions = torch.cat(predictions,dim=0).numpy()
            test_predictions[:,:,j] += predictions[:,:,j] / len(paths)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=5.0), HTML(value='')))

# %%
ss = pd.read_csv("../input/stanford-covid-vaccine/sample_submission.csv",index_col=0)

# %%
for n,row in tqdm(test.iterrows(),total=len(test)):
    test_id = row['id']
    seq_len = row['seq_length']
    for i in range(seq_len):
        for j,col in enumerate(['reactivity', 'deg_Mg_pH10', 'deg_Mg_50C']):
            ss.loc[test_id+'_'+str(i),col] = test_predictions[n,i,j]
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3634.0), HTML(value='')))

# %%
ss.to_csv("submission_cnn_{:5.5f}.csv".format(np.mean(cv_score)),index=True)
